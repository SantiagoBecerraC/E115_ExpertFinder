# %%
import pandas as pd
import numpy as np

# %%
from linkedin_api import Linkedin

# Authenticate using any Linkedin user account credentials
api = Linkedin('s.becerrac1@uniandes.edu.co', 'notbin-bemmyn-xymzU9')

# %% [markdown]
# `search_people` method:
# - keywords (str, optional) – Keywords to search on
# - current_company (list, optional) – A list of company URN IDs (str)
# - past_companies (list, optional) – A list of company URN IDs (str)
# - regions (list, optional) – A list of geo URN IDs (str)
# - industries (list, optional) – A list of industry URN IDs (str)
# - schools (list, optional) – A list of school URN IDs (str)
# - profile_languages (list, optional) – A list of 2-letter language codes (str)
# - contact_interests (list, optional) – A list containing one or both of “proBono” and “boardMember”
# - service_categories (list, optional) – A list of service category URN IDs (str)
# - network_depth (str, optional) – Deprecated, use network_depths. One of “F”, “S” and “O” (first, second and third+ respectively)
# - network_depths (list, optional) – A list containing one or many of “F”, “S” and “O” (first, second and third+
# respectively)
# - include_private_profiles (boolean, optional) – Include private profiles in search results. If False, only public profiles are included. Defaults to False
# - keyword_first_name (str, optional) – First name
# - keyword_last_name (str, optional) – Last name
# - keyword_title (str, optional) – Job title
# - keyword_company (str, optional) – Company name
# - keyword_school (str, optional) – School name
# - connection_of (str, optional) – Connection of LinkedIn user, given by profile URN ID
# - limit (int, optional) – Maximum length of the returned list, defaults to -1 (no limit)

# %%
# Search for software engineers at Google
people = api.search_people(
    keywords="machine learning computer vision",
    regions = ['103644278',],
    limit=100
)

people
# Out:
# [{'urn_id': 'ACoAAAYIxg8BxNB9SLTgtaZAbzzCHTpK4EyIq24',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning | Research Engineer',
#   'location': 'New York, NY',
#   'name': 'Lan G.'},
#  {'urn_id': 'ACoAAA230BgB8MfL272MJ70ArekRJmEzWPn3SXo',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'A machine learning engineer with scientific training, and with experience building computer vision ML products from the ground-up.',
#   'location': 'New York, NY',
#   'name': 'Yeu-Chern Harn'},
#  {'urn_id': 'ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life',
#   'location': 'West Palm Beach, FL',
#   'name': 'Mireille P. Feudjio T. (Ph.D)'},
#  {'urn_id': 'ACoAAC6HuYMB98gOsI0bTuXP8Mb4JAkPgMHFki8',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'AI Scientist',
#   'location': 'New York, NY',
#   'name': 'Grigorios Karageorgos'},
#  {'urn_id': 'ACoAADVFoOEBMtMrkmkLajeDpg10gPBma36_AJU',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning Engineer | MS 𝗔𝗿𝘁𝗶𝗳𝗶𝗰𝗶𝗮𝗹 𝗜𝗻𝘁𝗲𝗹𝗹𝗶𝗴𝗲𝗻𝗰𝗲 | Telecommunications Engineer | Soccer Coach | Student Athlete',
#   'location': 'Chicago, IL',
#   'name': 'Carlos Muñoz Losa'},
#  {'urn_id': 'ACoAAAUp8JgB8N_QpVPMUrsxS3llI8OqWC4lAcM',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'NCState | Image Processing | Computer Vision | Machine Learning | AgTech | Python',
#   'location': 'Raleigh, NC',
#   'name': 'Camilo Zuluaga'},
#  {'urn_id': 'ACoAAAWVTr4BxnoDopr-O3wmpqQovbAOCnDs7kA',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Computer Vision | Machine Learning',
#   'location': 'San Francisco Bay Area',
#   'name': 'Ravi Soni'},
#  {'urn_id': 'ACoAAC1rVwoBHfibUurnICJLawgsA480IIZ3Pzg',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Apple | Stanford | ML, Computer Vision & Robotics',
#   'location': 'Stanford, CA',
#   'name': 'Ishikaa Lunawat'},
#  {'urn_id': 'ACoAACKA4lsBdTY4MzO4YBM7Z2bw7W2wxOPCl4M',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning Engineer @ Dropbox',
#   'location': 'Seattle, WA',
#   'name': 'Gonzalo Garcia'},
#  {'urn_id': 'ACoAACM-PeUB56vEFSEv18S7qkEjR0vdHj_Vljw',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Data Science & ML @ Cummins Inc. | Carnegie Mellon University Alumnus | Machine Learning | Computer Vision | Robotics | Data Science',
#   'location': 'Greater Indianapolis',
#   'name': 'Parth Malpathak'},
#  {'urn_id': 'ACoAAAC0Ct8Bgi6GlFR1ViNAsNnHz1ronoWV_-o',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Manager, Computer Vision and Machine Learning',
#   'location': 'San Jose, CA',
#   'name': 'Nagendra Kamath'},
#  {'urn_id': 'ACoAAAxB5EoBkRXfU1F2Xr2nCUBn8TdTq1JxyFc',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Applied Research | Machine Learning | Computer Vision',
#   'location': 'Mountain View, CA',
#   'name': 'Nasim Shafiee'},
#  {'urn_id': 'ACoAABe-wpQBLij0SKsIwQh1PdmUh0evfqDhfKA',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Software Engineer at Bloomberg LP (Machine Learning Platform)',
#   'location': 'Jersey City, NJ',
#   'name': 'Matt Ryerkerk'},
#  {'urn_id': 'ACoAACzXYwQBfYFy-2QtNF9AFYVSW0cEZe9nU5s',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'MS CSE @ UCSD | AI Engineer | Deep Learning | Machine Learning | Computer Vision',
#   'location': 'San Diego, CA',
#   'name': 'Ishan Kumar Anand'},
#  {'urn_id': 'ACoAABv5Ag8BP8UDICAWnFpRd6JA7dAjWHTIffw',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Staff Data Scientist | Machine Learning | Computer Vision',
#   'location': 'San Francisco Bay Area',
#   'name': 'Amirhossein Bayat'},
#  {'urn_id': 'ACoAACCDAFsBTQ__33p0ITKc2QVRMPEvOUoxXds',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Graduate Research Assistant @ Rowan University | Machine Learning, Generative AI, Image Classification, Computer Vision',
#   'location': 'Glassboro, NJ',
#   'name': 'Atik Faysal'},
#  {'urn_id': 'ACoAADzKDaMBuawbCMNmzVXG6l2ES9fuVZDOnBY',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Applied mathematician | Machine Learning Engineer | Computer Vision',
#   'location': 'Houston, TX',
#   'name': 'Rosy Padilla'},
#  {'urn_id': 'ACoAAC35QHUBaG5XqmEZAfx2ieHqRffuo8xtzrE',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Carnegie Mellon Alumnus | Deep Learning | Machine Learning | Computer Vision | Perception',
#   'location': 'Pittsburgh, PA',
#   'name': 'Karan Veer Singh'},
#  {'urn_id': 'ACoAAAxA-7UB3h_iNNMKWxvDnREdmg1NKKal_rg',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning Scientist - M.S. in CS UC San Diego',
#   'location': 'Bellevue, WA',
#   'name': 'Victor Arango-Quiroga'},
#  {'urn_id': 'ACoAAAfx1m8BfGFUhoKMBYGbPMRjlTvOUJnEigE',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning Engineer @ Google',
#   'location': 'United States',
#   'name': 'Sampanna Kahu'},
#  {'urn_id': 'ACoAAABYjFQBEN2mpg_KDMIm0CtX3KTv71F-PIc',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning and AI for health care | computer vision | ex-AWS AI',
#   'location': 'Bellevue, WA',
#   'name': 'Rahul Bhotika'},
#  {'urn_id': 'ACoAABqkHNoBoRGSbFJYvHabSuEGWl2iwmfCXO4',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Sr. Machine Learning Engineer at Tesla | Computer Vision, Deep Learning, Fleet Learning',
#   'location': 'Sunnyvale, CA',
#   'name': 'Paritosh Mittal'},
#  {'urn_id': 'ACoAAAwaP_wB1nE2KJbPthJapjC04gb887Duyvs',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning Researcher | Explainable AI Advocate | Poet | Topology Dilettante',
#   'location': 'Rolla, MO',
#   'name': 'Raghu Y.'},
#  {'urn_id': 'ACoAAB8-8XQBQs7QoxMmxvccFHDzBEYumi_JSPM',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Software Developer @ Flexday AI | Machine Learning and Computer Vision | Robotics',
#   'location': 'United States',
#   'name': 'Pavan R Shetty'},
#  {'urn_id': 'ACoAAAFhl6UBm7F760lrqtHApU77gOcNf0lhzIE',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Research/Engineering Leader (Machine learning, Computer Vision, Computer Graphics) at Netflix',
#   'location': 'San Francisco Bay Area',
#   'name': 'Hossein Taghavi'},
#  {'urn_id': 'ACoAAB5irP4Buu5eq-94QNUWgX5COOPRSu3WgVc',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Computer Vision & Machine Learning | Robotics & ML @Carnegie Mellon',
#   'location': 'Sunnyvale, CA',
#   'name': 'Animesh Dhagat'},
#  {'urn_id': 'ACoAAAXPYXcByfSpeErpq_s8zOfw6yUDBe7Ry3U',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Director of Data Science (Machine Learning & Computer Vision)',
#   'location': 'Greater Chicago Area',
#   'name': 'Neda Hantehzadeh, PhD'},
#  {'urn_id': 'ACoAACMIgDYB1RyJPmTrMKFK2QBxXzUvoVsPHR0',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Data Scientist at HiLabs | Johns Hopkins | Gen AI | LLM | Machine Learning | Computer Vision',
#   'location': 'San Francisco Bay Area',
#   'name': 'Venkat Mukthineni'},
#  {'urn_id': 'ACoAABu8q3cB5V0Q1MuB2xj9RUnIptodgP4dekc',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning + Robotics, Computer Vision • NYU & BITS Pilani alum',
#   'location': 'San Francisco Bay Area',
#   'name': 'Aditya Wagh'},
#  {'urn_id': 'ACoAACDLWNIBN-xp4CPfADc5kJnEa43EMB-cJBE',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'ML Engineer @ Tinder | Prev - AI @ LinkedIn | CS Grad @ ASU',
#   'location': 'San Francisco Bay Area',
#   'name': 'Skanda Suresh'},
#  {'urn_id': 'ACoAABwDC6EBxt9sKNJg3nWCGDyC9MwbrUsmfi4',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning Engineer | AI Research Finance',
#   'location': 'Madison, WI',
#   'name': 'Arturo Polanco Lozano'},
#  {'urn_id': 'ACoAAD5hJhUBRsuNnOMqnLmkOdCQNixLUIGPdvM',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Data Scientist | Python | Machine Learning | Deep Learning | Computer Vision | Gen AI',
#   'location': 'Jersey City, NJ',
#   'name': 'Muktika M.'},
#  {'urn_id': 'ACoAAAfhLHsBH_RJ_78S8K9n-YsPqUYxHku56oA',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Autonomous Driving, Robotics, Computer Vision and Machine Learning',
#   'location': 'San Francisco Bay Area',
#   'name': 'Xinyu Cindy Xu'},
#  {'urn_id': 'ACoAACewYhUBeBxmi8NpLIEUT1Onx_ffXHInTAY',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Software Engineer | Machine Learning | Computer Vision | Transformers | AI Agents',
#   'location': 'Austin, TX',
#   'name': 'Pritish Mishra'},
#  {'urn_id': 'ACoAAABpgiUBLCcfxocRIh87TbTFlqvnn7MWDG4',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Research/Engineering in Computer Vision , Machine Learning and Robotics',
#   'location': 'Austin, Texas Metropolitan Area',
#   'name': 'Chaitanya Desai'},
#  {'urn_id': 'ACoAACc_LEEBfC8ugdR0pk9Rc0VZHL5LLd1LpOc',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'PhD candidate at Johns Hopkins University | Applied Mathematician | Machine Learning Researcher | Fulbright Scholar',
#   'location': 'Baltimore, MD',
#   'name': 'Daniel Lopez-Castano'},
#  {'urn_id': 'ACoAADI0mccByqzCxPKnnXwgZ9kWQeDuq_xUnrg',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning Engineer | Specialized in Computer Vision, Reinforcement Learning',
#   'location': 'Walnut Creek, CA',
#   'name': 'Sai venkat reddy sheri'},
#  {'urn_id': 'ACoAAABvvKQB6iaA3VZpLeI1YzKcbHt5Hx0aCkU',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Distinguished Engineer - Machine Learning & Computer Vision',
#   'location': 'Santa Clara, CA',
#   'name': 'Kiran G.'},
#  {'urn_id': 'ACoAAADVk-wBPr0xzjNLCQ3skJ0Zum8Mf3bSFhA',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Computer Vision & Machine Learning Manager at Apple',
#   'location': 'San Francisco Bay Area',
#   'name': 'Lizi Ottens'},
#  {'urn_id': 'ACoAABwMIeEBl6gcwf9GDv_aAs5QmyyOv0FK6qQ',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Perception @ Nuro | Machine Learning, Computer Vision, Autonomous Robotics.',
#   'location': 'United States',
#   'name': 'Akshay Sharma'},
#  {'urn_id': 'ACoAAApYWLUB_RUc0YAnOsvR1GhKD4S44QoXTmU',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning | Computer Vision | LLMs',
#   'location': 'San Francisco, CA',
#   'name': 'Vasanth Balakrishnan'},
#  {'urn_id': 'ACoAAAl4j_oBoXZwfWFJ8PkkBpIvftXOtXzonas',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Applied Scientist II at Artificial General Intelligence (AGI), Amazon (Nova) | GenAI, Machine Learning, Computer Vision | ČVUT | CMU | IIIT-H',
#   'location': 'San Francisco, CA',
#   'name': 'Yash Patel'},
#  {'urn_id': 'ACoAABNdZpMBYzxHLIDNHZ5cGiaiD6ZHxYq3zpY',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning & Computer Vision Engineer @ Apple | x-Google | Mentor',
#   'location': 'Mountain View, CA',
#   'name': 'Alvise M.'},
#  {'urn_id': 'ACoAADQg3ckBwSY3crDiFbBC2jZhUwg0SA4-wCY',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Software Engineer @ Apple | SWE, Machine Learning, Computer Vision, and Graphics | Ex Amazon',
#   'location': 'Austin, Texas Metropolitan Area',
#   'name': 'Nabhan Sazzad'},
#  {'urn_id': 'ACoAABzISdIB7O-0BR10NQCHe3tlFy_iSrmWUVM',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning Engineer | Computer Vision & Robotics Engineer | Production ML Systems',
#   'location': 'United States',
#   'name': 'Sandeep Kota'},
#  {'urn_id': 'ACoAAAhIA2cBfA3p99kU7ENeSIYxZPa5GqzY0rw',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning, Computer Vision, NLP',
#   'location': 'Los Angeles, CA',
#   'name': 'Ali Borji'},
#  {'urn_id': 'ACoAACINe2gB1uTBLfzvspgmPE_9enJM4lbB8ts',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning | Neuroscience | Hard Problems',
#   'location': 'Greater Seattle Area',
#   'name': 'David Boe'},
#  {'urn_id': 'ACoAABIVD-IBbCpSM2cYRI76LGkaOxlk6Tfic30',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Director at Apple - Computer Vision & Machine Learning',
#   'location': 'Palo Alto, CA',
#   'name': 'Selim Ben Himane'},
#  {'urn_id': 'ACoAAC1wO2MBvlJvr3I_egnGAXRkA9HqQV_xgJw',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine learning engineer at Strayos | NYU Alum | Computer vision | DL/ML',
#   'location': 'Brooklyn, NY',
#   'name': 'Sai Krishna P.'},
#  {'urn_id': 'ACoAAAFDk_UBEuvndP-nQ5WMBeIxRWAB2uAVojU',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Director Machine Learning @Ericsson, computer vision for digital transformation.',
#   'location': 'San Francisco Bay Area',
#   'name': 'Taesuh Park'},
#  {'urn_id': 'ACoAAAHegT0Bv6uyoecTWO-Ro1APddd_1X30t58',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Director of Machine Learning @ Apple | Video Computer Vision - Human Understanding',
#   'location': 'San Francisco Bay Area',
#   'name': 'Kelsey Ho'},
#  {'urn_id': 'ACoAAAvg71sB33-qW4LoVQhIhyHJlRDweALcJI0',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Software Engineer @ Meta | PhD, Image Processing, Computer Vision, Deep Learning, Machine Learning',
#   'location': 'San Diego, CA',
#   'name': 'Songan Mao'},
#  {'urn_id': 'ACoAABfgw28BsEgxVGPnjU1M3POpyMNRXlOTCPk',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning Engineer at Helm.ai',
#   'location': 'Greater Boston',
#   'name': 'Bruno Costa Rendon'},
#  {'urn_id': 'ACoAAD33ZDUBEvbITJSElZJ4PJBV0NHA5TLF_38',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'ECE @ UT Austin | Software Engineer | AI /ML & Computer Vision | Data Science | Open to Work',
#   'location': 'Austin, TX',
#   'name': 'Natalie Leal Blanco'},
#  {'urn_id': 'ACoAAAKhTOsBDkT_d6Txj2o6dY8JsL7a8Z6ETdI',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Principal data scientist ( machine learning, ecology, computer vision, medical imaging, healthcare, econometrics)',
#   'location': 'Santa Clara, CA',
#   'name': 'Vikas Ramachandra'},
#  {'urn_id': 'ACoAABuLw18Bb8troOpbvKHkAq1SMmHWXC5ZGFI',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Data Scientist | Machine Learning | SQL | Gen AI | Databricks | MLOPS | Azure | AWS | MLflow | Docker | Marketing mix modeling | Satellite Imaging | Computer Vision | GIS | AI',
#   'location': 'United States',
#   'name': 'Sanket Pathak'},
#  {'urn_id': 'ACoAADDDF1sBFeot-HCjr-H-bW3c8g9qsxB1Ak0',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning Engineer | Computer Vision, Generative AI',
#   'location': 'Boston, MA',
#   'name': 'Uday Shankar Gattu'},
#  {'urn_id': 'ACoAABtnMRsBQEG0gtHvJqSCoafnmJbpc-QZm00',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Data Scientist | Al | Machine Learning | Recommendation Systems| Deep Learning I Customer analytics | Computer Vision | Kaggle Expert | AWS Sagemaker MLOps | MSc. in Data Science',
#   'location': 'Dallas-Fort Worth Metroplex',
#   'name': 'Pavan Reddy Mogili'},
#  {'urn_id': 'ACoAAAF5SikBJlcoCtyAOqxgK71iRHWlLRl_smM',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Computer Vision, Machine Learning, Robotics',
#   'location': 'Brooklyn, NY',
#   'name': 'Frank Preiswerk'},
#  {'urn_id': 'ACoAAB2_GIUB19tvv_EEi_KQH7pt2Cehbt_0KN4',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'AI Researcher | Ph.D. Candidate',
#   'location': 'United States',
#   'name': 'Andres Ramirez-Jaime'},
#  {'urn_id': 'ACoAAALTn9oB4HdFQGV_iQvSlW7gdfUDsWqnQ5U',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Research Manager | PhD | Machine Learning, Computer Vision & Generative AI Expert | Driving Innovation at Netflix',
#   'location': 'San Francisco, CA',
#   'name': 'Benjamin Klein'},
#  {'urn_id': 'ACoAACbB8GsBMaESCCcrbZFBZYGYEQZs8IKHhEo',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Robotics and AI | Computer Vision',
#   'location': 'United States',
#   'name': 'Harshang Chhaya'},
#  {'urn_id': 'ACoAABUurKcBQSjXQnPmv47oRHRQncWrH30b5VY',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning/ Computer Vision Talent Advisor',
#   'location': 'Cupertino, CA',
#   'name': 'Braeden Burnett'},
#  {'urn_id': 'ACoAAAOLxVsBnDFVVv4ncvq8-ZdAAp6_xwOEvWo',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist | AI | ML | Computer Vision | NLP',
#   'location': 'Atlanta Metropolitan Area',
#   'name': 'Suresh Mani'},
#  {'urn_id': 'ACoAAChaxFwB7C_i2Ym-lBPG-P2WUGlee-ie6cs',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Passionate Data Scientist | Data Engineer | Turning Data into Insights | Machine Learning | Data Analysis & Visualization',
#   'location': 'New York City Metropolitan Area',
#   'name': 'Jeremy Mathew'},
#  {'urn_id': 'ACoAAC_QLdMBqzUGQuZDANnXnSfjmGKgQT3iCbY',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning Engineer - Perception @ Torc Robotics',
#   'location': 'Worcester, MA',
#   'name': 'Loahit Krishnamurthy'},
#  {'urn_id': 'ACoAADVzPhoBDiFUdxTv_DNBpyrcg4wBd1oyf3A',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Sr Data Scientist | Machine Learning Engineer | AI Engineer | LLM Engineer | MLOps | LLMOps | Python | NLP | Spark | Azure | Generative AI | Computer Vision | LLM',
#   'location': 'United States',
#   'name': 'Gabriel Barros Lins'},
#  {'urn_id': 'ACoAACgZTeIBzpHWrWlNS2-UPiUMCbtYgF9P9po',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist | AI | Machine Learning | Recommendation Systems| Deep Learning | Customer analytics | Computer Vision | Kaggle Expert | AWS Sagemaker MLOps | MSc. in Data Science',
#   'location': 'United States',
#   'name': 'Shruti kunapuli'},
#  {'urn_id': 'ACoAADAGBrYBb8zv44R6wRrUEWDyKTDPGqEKX78',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Analyst & Scientist | SQL, Python, Cloud Technologies | Passionate about AI & Machine Learning',
#   'location': 'Miami, FL',
#   'name': 'Yanet Fernandez'},
#  {'urn_id': 'ACoAACQ1IIIBtSaPPZQWXSIPE7eLIuubMHs4fc4',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Data Scientist | Gen AI Engineer | Expert in Machine Learning, NLP, and Computer Vision',
#   'location': 'Houston, TX',
#   'name': 'shiva reddy'},
#  {'urn_id': 'ACoAAAINkF8B7_XL7j0q_MlsZBQH4C2GP5DQ1Z4',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Harvard / Broad Institute / MIT Scientist || Machine Learning || Computer Vision || Data Scientist || Deep Learning || AI Consultant || AI Solution Architect || AI Project Manager',
#   'location': 'San Francisco, CA',
#   'name': 'Humayun Irshad'},
#  {'urn_id': 'ACoAAAELurwBQSt0xL0cjaicMCioSWw5EU_ZXYI',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Scientist/Engineer on Computer Vision/Machine Learning/Autonomous Driving/Embodied AI',
#   'location': 'Sunnyvale, CA',
#   'name': 'Yu Huang'},
#  {'urn_id': 'ACoAAB7vaL8BpT1vAUEL1n4GzkHgSlkzj87gPVQ',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Artificial Intelligence Specialist | Deep Learning | Computer Vision | Machine Learning',
#   'location': 'Miami, FL',
#   'name': 'Steven Parra'},
#  {'urn_id': 'ACoAAAz9NS8BOho49muh0f65sV9_AedvEsz4MWU',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Staff Machine Learning Engineer @ AKOOL | Computer Vision, Deep Learning',
#   'location': 'San Jose, CA',
#   'name': 'Yixin Jin'},
#  {'urn_id': 'ACoAABVzULAB7NNWu4vePuVq-VXpXEjTNqXXaUo',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Artificial Intelligence | Robotics | Computer Vision | Machine Learning',
#   'location': 'San Francisco Bay Area',
#   'name': 'Siddharth Agarwal'},
#  {'urn_id': 'ACoAAC8npxcBMnddMFIwXImlqI7-bxDu5CvmPmM',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning Engineer - Data Scientist - Biomedical Engineer NLP | LLM | CV | ML | DS | AWS | Python',
#   'location': 'United States',
#   'name': 'Tomás Echavarría Bayter'},
#  {'urn_id': 'ACoAAAYQiuABqj1mxkYapYMYLHH-tgJTMAO1rLM',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning | Generative AI | LLMs | Computer Graphics & Computer Vision | Distributed Computing',
#   'location': 'Philadelphia, PA',
#   'name': 'Kaihua Ding, Ph.D.'},
#  {'urn_id': 'ACoAABlCiToBLZJXs70kul3SNyCTsMqvYVNvZfU',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning @7ai | LLMs | Computer Vision | AWS ML Certified',
#   'location': 'Boston, MA',
#   'name': 'Likith Ponnanna'},
#  {'urn_id': 'ACoAADSjD2oB-uJRtmwbiPMQ47qC5Oxei-oNpYQ',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Graduate Research Assistant at NSF AI Institute | Data Science, Machine Learning & Computer Vision',
#   'location': 'Tuskegee Institute, AL',
#   'name': 'Md Al Siam'},
#  {'urn_id': 'ACoAABMa2I0B15zhs6DWvkkHJmuSl0wXPoq_Sc0',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning Group Manager',
#   'location': 'New York City Metropolitan Area',
#   'name': 'Lior Gazit'},
#  {'urn_id': 'ACoAAB973uMBBByFr6zM62bF6vjR3o1ntk-moaI',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'GEN AI | LLMs | NLP | Machine Learning | Computer Vision Engineer | Data Scientist',
#   'location': 'New York, NY',
#   'name': 'Avinash Reddy Rangu'},
#  {'urn_id': 'ACoAADvRHYEBKQzVa4EkbtJj3xEn2CYk5qwjrEU',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Medical AI Scientist / Engineer',
#   'location': 'United States',
#   'name': 'Mike Powell'},
#  {'urn_id': 'ACoAACSRPzIBQqmavw7Ec_C74AMaLpTlxBoP2gA',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'AI Engineer | Carnegie Mellon University Alumnus | Machine Learning | Gen AI',
#   'location': 'Washington DC-Baltimore Area',
#   'name': 'Prakhar Bhardwaj'},
#  {'urn_id': 'ACoAABB0dScBqkwPgvCN-Jcz8aCl-ZMUhbKT9GU',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning Scientist | AI for Drug Discovery | Neuroscience PhD',
#   'location': 'Boston, MA',
#   'name': 'Asa Barth-Maron'},
#  {'urn_id': 'ACoAADPvsD4Bw0zjZlRHGpZkSdr2xhF_r5l4dMk',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning | MLOps | Gen Ai | NLP | Computer Vision | LLMs | RAG | Ai Agents',
#   'location': 'Irving, TX',
#   'name': 'Sai Vivek Katkuri'},
#  {'urn_id': 'ACoAAAJyWCsBBv5g8oCEfOhdGlOItcQKa0a5C2U',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning @ Meta',
#   'location': 'Greater Boston',
#   'name': 'Jae-Woo Choi, Ph.D.'},
#  {'urn_id': 'ACoAABRKMwIBJ-c1ISDWEOPHUY-RjRs4Igw2sN8',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Senior Machine Learning Engineer, FinTech, Retail, Healthcare, Computer Vision',
#   'location': 'Reston, VA',
#   'name': 'Zuraiz Uddin'},
#  {'urn_id': 'ACoAACeHkPoBYNUPCEYNYXGj8B4vVMK_EIeFs-w',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Engineer with expertise in Applied AI and R&D. Building the future of autonomous AI.',
#   'location': 'San Francisco, CA',
#   'name': 'Pratyush Shukla'},
#  {'urn_id': 'ACoAABYIwGQBBYZNnZURluoZoUZPcR2jw45r5Q8',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Machine Learning at Pinterest',
#   'location': 'Greater Seattle Area',
#   'name': 'Tianqi Wang'},
#  {'urn_id': 'ACoAADA6AB4Bn3mbvPTW0blcb-yNfuHzdUQuQjg',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Ex- Machine Learning Research Engineer at Dassault Systemes | Machine Learning | Generative AI | Deep Learning | Computer Vision | LLM',
#   'location': 'United States',
#   'name': 'Shrishailya Chavan'},
#  {'urn_id': 'ACoAAD7mIRMBK1baYdxDgjCCGoD61BtdIuiA3qM',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning Engineer | AI | Data Scientist | NLP | Deep Learning | MSCS (AI) Graduate @ Kennesaw State University',
#   'location': 'Atlanta Metropolitan Area',
#   'name': 'Drashtee Parmar'},
#  {'urn_id': 'ACoAAD6MojUBDiDLsmOebLaRVWj70oOQ0cXKzSs',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Research Assistant || Machine Learning or Deep Learning for Computer Vision, Natural Language Processing, HCI, and Truth AI',
#   'location': 'Pasadena, CA',
#   'name': 'Tan H. Nguyen'},
#  {'urn_id': 'ACoAABkyRX0BA1mMVsU5QuC-lC0zrGq_OWASrm8',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Applied Scientist @ Amazon Web Services (AWS) || PhD in Computer Engineering, UMBC',
#   'location': 'Duluth, GA',
#   'name': 'Hasib-Al Rashid'},
#  {'urn_id': 'ACoAACMMjY8Bb3aulhVXcc0hi2yJZbeaSETr7vQ',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Full Stack AI/ML Engineer | Specializing in NLP, Deep Learning, Machine Learning and Computer Vision',
#   'location': 'Lititz, PA',
#   'name': 'Awais P.'},
#  {'urn_id': 'ACoAABErTTgBiV1_aB0QBCUe6gJ5GHoklCjb5mg',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning | Computer Vision | Gen AI | Data Science | Ex-Novartis | AI in Drug Discovery | Research Scholar@ Harvard | Postdoc scholar@ Stanford',
#   'location': 'San Francisco Bay Area',
#   'name': 'Mojtaba S.'},
#  {'urn_id': 'ACoAAAFdY8MBsQ4jXUX6a_549DCrejf7mqyeeMg',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Computer Vision Machine Learning Engineer',
#   'location': 'United States',
#   'name': 'Vishwanath Sindagi'},
#  {'urn_id': 'ACoAACcxrt0B3q8sOSD4z0GU-OEtAn8SxeZ61oc',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Research Scientist @ Honda Research Institute USA | PhD @ JHU | Trustworthy AI, Machine Learning, Computer Vision',
#   'location': 'San Jose, CA',
#   'name': 'Shao-Yuan Lo'},
#  {'urn_id': 'ACoAAC7fwDEB8O9A_PdioC5y-YLdR6y7C7omjmI',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Machine Learning Engineer | Data Scientist | AI Innovator',
#   'location': 'United States',
#   'name': 'Emmanuel Boniface'},
#  {'urn_id': 'ACoAADHxWZ4Bzn6RRCEQQjZgpLDOXWbA8YroYGI',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Robotics Research @Northeastern University | Perception | Computer Vision | SLAM | Deep learning | Machine Learning',
#   'location': 'Boston, MA',
#   'name': 'Mohammed Irfan Ali'},
#  {'urn_id': 'ACoAAB-RKioBD3nmoHl06JTRA1kwO1H2OQF8mqY',
#   'distance': 'DISTANCE_3',
#   'jobtitle': 'Postdoctoral Researcher @ MIT CSAIL | Machine Learning | Computer Vision | Biomedical Imaging',
#   'location': 'Cambridge, MA',
#   'name': 'Neel Dey'}]

# %%
for person in people:
    print(f"Name: {person['name']}")
    print(f"Title: {person['jobtitle']}")
    print(f"Location: {person['location']}")
    print("---")
# Out:
# Name: Lan G.
# Title: Machine Learning | Research Engineer
# Location: New York, NY
# ---
# Name: Yeu-Chern Harn
# Title: A machine learning engineer with scientific training, and with experience building computer vision ML products from the ground-up.
# Location: New York, NY
# ---
# Name: Mireille P. Feudjio T. (Ph.D)
# Title: Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life
# Location: West Palm Beach, FL
# ---
# Name: Grigorios Karageorgos
# Title: AI Scientist
# Location: New York, NY
# ---
# Name: Carlos Muñoz Losa
# Title: Machine Learning Engineer | MS 𝗔𝗿𝘁𝗶𝗳𝗶𝗰𝗶𝗮𝗹 𝗜𝗻𝘁𝗲𝗹𝗹𝗶𝗴𝗲𝗻𝗰𝗲 | Telecommunications Engineer | Soccer Coach | Student Athlete
# Location: Chicago, IL
# ---
# Name: Camilo Zuluaga
# Title: NCState | Image Processing | Computer Vision | Machine Learning | AgTech | Python
# Location: Raleigh, NC
# ---
# Name: Ravi Soni
# Title: Computer Vision | Machine Learning
# Location: San Francisco Bay Area
# ---
# Name: Ishikaa Lunawat
# Title: Apple | Stanford | ML, Computer Vision & Robotics
# Location: Stanford, CA
# ---
# Name: Gonzalo Garcia
# Title: Machine Learning Engineer @ Dropbox
# Location: Seattle, WA
# ---
# Name: Parth Malpathak
# Title: Data Science & ML @ Cummins Inc. | Carnegie Mellon University Alumnus | Machine Learning | Computer Vision | Robotics | Data Science
# Location: Greater Indianapolis
# ---
# Name: Nagendra Kamath
# Title: Manager, Computer Vision and Machine Learning
# Location: San Jose, CA
# ---
# Name: Nasim Shafiee
# Title: Applied Research | Machine Learning | Computer Vision
# Location: Mountain View, CA
# ---
# Name: Matt Ryerkerk
# Title: Software Engineer at Bloomberg LP (Machine Learning Platform)
# Location: Jersey City, NJ
# ---
# Name: Ishan Kumar Anand
# Title: MS CSE @ UCSD | AI Engineer | Deep Learning | Machine Learning | Computer Vision
# Location: San Diego, CA
# ---
# Name: Amirhossein Bayat
# Title: Staff Data Scientist | Machine Learning | Computer Vision
# Location: San Francisco Bay Area
# ---
# Name: Atik Faysal
# Title: Graduate Research Assistant @ Rowan University | Machine Learning, Generative AI, Image Classification, Computer Vision
# Location: Glassboro, NJ
# ---
# Name: Rosy Padilla
# Title: Applied mathematician | Machine Learning Engineer | Computer Vision
# Location: Houston, TX
# ---
# Name: Karan Veer Singh
# Title: Carnegie Mellon Alumnus | Deep Learning | Machine Learning | Computer Vision | Perception
# Location: Pittsburgh, PA
# ---
# Name: Victor Arango-Quiroga
# Title: Machine Learning Scientist - M.S. in CS UC San Diego
# Location: Bellevue, WA
# ---
# Name: Sampanna Kahu
# Title: Machine Learning Engineer @ Google
# Location: United States
# ---
# Name: Rahul Bhotika
# Title: Machine Learning and AI for health care | computer vision | ex-AWS AI
# Location: Bellevue, WA
# ---
# Name: Paritosh Mittal
# Title: Sr. Machine Learning Engineer at Tesla | Computer Vision, Deep Learning, Fleet Learning
# Location: Sunnyvale, CA
# ---
# Name: Raghu Y.
# Title: Machine Learning Researcher | Explainable AI Advocate | Poet | Topology Dilettante
# Location: Rolla, MO
# ---
# Name: Pavan R Shetty
# Title: Software Developer @ Flexday AI | Machine Learning and Computer Vision | Robotics
# Location: United States
# ---
# Name: Hossein Taghavi
# Title: Research/Engineering Leader (Machine learning, Computer Vision, Computer Graphics) at Netflix
# Location: San Francisco Bay Area
# ---
# Name: Animesh Dhagat
# Title: Computer Vision & Machine Learning | Robotics & ML @Carnegie Mellon
# Location: Sunnyvale, CA
# ---
# Name: Neda Hantehzadeh, PhD
# Title: Director of Data Science (Machine Learning & Computer Vision)
# Location: Greater Chicago Area
# ---
# Name: Venkat Mukthineni
# Title: Data Scientist at HiLabs | Johns Hopkins | Gen AI | LLM | Machine Learning | Computer Vision
# Location: San Francisco Bay Area
# ---
# Name: Aditya Wagh
# Title: Machine Learning + Robotics, Computer Vision • NYU & BITS Pilani alum
# Location: San Francisco Bay Area
# ---
# Name: Skanda Suresh
# Title: ML Engineer @ Tinder | Prev - AI @ LinkedIn | CS Grad @ ASU
# Location: San Francisco Bay Area
# ---
# Name: Arturo Polanco Lozano
# Title: Machine Learning Engineer | AI Research Finance
# Location: Madison, WI
# ---
# Name: Muktika M.
# Title: Data Scientist | Python | Machine Learning | Deep Learning | Computer Vision | Gen AI
# Location: Jersey City, NJ
# ---
# Name: Xinyu Cindy Xu
# Title: Autonomous Driving, Robotics, Computer Vision and Machine Learning
# Location: San Francisco Bay Area
# ---
# Name: Pritish Mishra
# Title: Software Engineer | Machine Learning | Computer Vision | Transformers | AI Agents
# Location: Austin, TX
# ---
# Name: Chaitanya Desai
# Title: Research/Engineering in Computer Vision , Machine Learning and Robotics
# Location: Austin, Texas Metropolitan Area
# ---
# Name: Daniel Lopez-Castano
# Title: PhD candidate at Johns Hopkins University | Applied Mathematician | Machine Learning Researcher | Fulbright Scholar
# Location: Baltimore, MD
# ---
# Name: Sai venkat reddy sheri
# Title: Machine Learning Engineer | Specialized in Computer Vision, Reinforcement Learning
# Location: Walnut Creek, CA
# ---
# Name: Kiran G.
# Title: Distinguished Engineer - Machine Learning & Computer Vision
# Location: Santa Clara, CA
# ---
# Name: Lizi Ottens
# Title: Computer Vision & Machine Learning Manager at Apple
# Location: San Francisco Bay Area
# ---
# Name: Akshay Sharma
# Title: Perception @ Nuro | Machine Learning, Computer Vision, Autonomous Robotics.
# Location: United States
# ---
# Name: Vasanth Balakrishnan
# Title: Machine Learning | Computer Vision | LLMs
# Location: San Francisco, CA
# ---
# Name: Yash Patel
# Title: Applied Scientist II at Artificial General Intelligence (AGI), Amazon (Nova) | GenAI, Machine Learning, Computer Vision | ČVUT | CMU | IIIT-H
# Location: San Francisco, CA
# ---
# Name: Alvise M.
# Title: Machine Learning & Computer Vision Engineer @ Apple | x-Google | Mentor
# Location: Mountain View, CA
# ---
# Name: Nabhan Sazzad
# Title: Software Engineer @ Apple | SWE, Machine Learning, Computer Vision, and Graphics | Ex Amazon
# Location: Austin, Texas Metropolitan Area
# ---
# Name: Sandeep Kota
# Title: Machine Learning Engineer | Computer Vision & Robotics Engineer | Production ML Systems
# Location: United States
# ---
# Name: Ali Borji
# Title: Machine Learning, Computer Vision, NLP
# Location: Los Angeles, CA
# ---
# Name: David Boe
# Title: Machine Learning | Neuroscience | Hard Problems
# Location: Greater Seattle Area
# ---
# Name: Selim Ben Himane
# Title: Director at Apple - Computer Vision & Machine Learning
# Location: Palo Alto, CA
# ---
# Name: Sai Krishna P.
# Title: Machine learning engineer at Strayos | NYU Alum | Computer vision | DL/ML
# Location: Brooklyn, NY
# ---
# Name: Taesuh Park
# Title: Director Machine Learning @Ericsson, computer vision for digital transformation.
# Location: San Francisco Bay Area
# ---
# Name: Kelsey Ho
# Title: Director of Machine Learning @ Apple | Video Computer Vision - Human Understanding
# Location: San Francisco Bay Area
# ---
# Name: Songan Mao
# Title: Software Engineer @ Meta | PhD, Image Processing, Computer Vision, Deep Learning, Machine Learning
# Location: San Diego, CA
# ---
# Name: Bruno Costa Rendon
# Title: Machine Learning Engineer at Helm.ai
# Location: Greater Boston
# ---
# Name: Natalie Leal Blanco
# Title: ECE @ UT Austin | Software Engineer | AI /ML & Computer Vision | Data Science | Open to Work
# Location: Austin, TX
# ---
# Name: Vikas Ramachandra
# Title: Principal data scientist ( machine learning, ecology, computer vision, medical imaging, healthcare, econometrics)
# Location: Santa Clara, CA
# ---
# Name: Sanket Pathak
# Title: Data Scientist | Machine Learning | SQL | Gen AI | Databricks | MLOPS | Azure | AWS | MLflow | Docker | Marketing mix modeling | Satellite Imaging | Computer Vision | GIS | AI
# Location: United States
# ---
# Name: Uday Shankar Gattu
# Title: Machine Learning Engineer | Computer Vision, Generative AI
# Location: Boston, MA
# ---
# Name: Pavan Reddy Mogili
# Title: Data Scientist | Al | Machine Learning | Recommendation Systems| Deep Learning I Customer analytics | Computer Vision | Kaggle Expert | AWS Sagemaker MLOps | MSc. in Data Science
# Location: Dallas-Fort Worth Metroplex
# ---
# Name: Frank Preiswerk
# Title: Computer Vision, Machine Learning, Robotics
# Location: Brooklyn, NY
# ---
# Name: Andres Ramirez-Jaime
# Title: AI Researcher | Ph.D. Candidate
# Location: United States
# ---
# Name: Benjamin Klein
# Title: Research Manager | PhD | Machine Learning, Computer Vision & Generative AI Expert | Driving Innovation at Netflix
# Location: San Francisco, CA
# ---
# Name: Harshang Chhaya
# Title: Robotics and AI | Computer Vision
# Location: United States
# ---
# Name: Braeden Burnett
# Title: Machine Learning/ Computer Vision Talent Advisor
# Location: Cupertino, CA
# ---
# Name: Suresh Mani
# Title: Data Scientist | AI | ML | Computer Vision | NLP
# Location: Atlanta Metropolitan Area
# ---
# Name: Jeremy Mathew
# Title: Passionate Data Scientist | Data Engineer | Turning Data into Insights | Machine Learning | Data Analysis & Visualization
# Location: New York City Metropolitan Area
# ---
# Name: Loahit Krishnamurthy
# Title: Machine Learning Engineer - Perception @ Torc Robotics
# Location: Worcester, MA
# ---
# Name: Gabriel Barros Lins
# Title: Sr Data Scientist | Machine Learning Engineer | AI Engineer | LLM Engineer | MLOps | LLMOps | Python | NLP | Spark | Azure | Generative AI | Computer Vision | LLM
# Location: United States
# ---
# Name: Shruti kunapuli
# Title: Data Scientist | AI | Machine Learning | Recommendation Systems| Deep Learning | Customer analytics | Computer Vision | Kaggle Expert | AWS Sagemaker MLOps | MSc. in Data Science
# Location: United States
# ---
# Name: Yanet Fernandez
# Title: Data Analyst & Scientist | SQL, Python, Cloud Technologies | Passionate about AI & Machine Learning
# Location: Miami, FL
# ---
# Name: shiva reddy
# Title: Data Scientist | Gen AI Engineer | Expert in Machine Learning, NLP, and Computer Vision
# Location: Houston, TX
# ---
# Name: Humayun Irshad
# Title: Harvard / Broad Institute / MIT Scientist || Machine Learning || Computer Vision || Data Scientist || Deep Learning || AI Consultant || AI Solution Architect || AI Project Manager
# Location: San Francisco, CA
# ---
# Name: Yu Huang
# Title: Scientist/Engineer on Computer Vision/Machine Learning/Autonomous Driving/Embodied AI
# Location: Sunnyvale, CA
# ---
# Name: Steven Parra
# Title: Artificial Intelligence Specialist | Deep Learning | Computer Vision | Machine Learning
# Location: Miami, FL
# ---
# Name: Yixin Jin
# Title: Staff Machine Learning Engineer @ AKOOL | Computer Vision, Deep Learning
# Location: San Jose, CA
# ---
# Name: Siddharth Agarwal
# Title: Artificial Intelligence | Robotics | Computer Vision | Machine Learning
# Location: San Francisco Bay Area
# ---
# Name: Tomás Echavarría Bayter
# Title: Machine Learning Engineer - Data Scientist - Biomedical Engineer NLP | LLM | CV | ML | DS | AWS | Python
# Location: United States
# ---
# Name: Kaihua Ding, Ph.D.
# Title: Machine Learning | Generative AI | LLMs | Computer Graphics & Computer Vision | Distributed Computing
# Location: Philadelphia, PA
# ---
# Name: Likith Ponnanna
# Title: Machine Learning @7ai | LLMs | Computer Vision | AWS ML Certified
# Location: Boston, MA
# ---
# Name: Md Al Siam
# Title: Graduate Research Assistant at NSF AI Institute | Data Science, Machine Learning & Computer Vision
# Location: Tuskegee Institute, AL
# ---
# Name: Lior Gazit
# Title: Machine Learning Group Manager
# Location: New York City Metropolitan Area
# ---
# Name: Avinash Reddy Rangu
# Title: GEN AI | LLMs | NLP | Machine Learning | Computer Vision Engineer | Data Scientist
# Location: New York, NY
# ---
# Name: Mike Powell
# Title: Medical AI Scientist / Engineer
# Location: United States
# ---
# Name: Prakhar Bhardwaj
# Title: AI Engineer | Carnegie Mellon University Alumnus | Machine Learning | Gen AI
# Location: Washington DC-Baltimore Area
# ---
# Name: Asa Barth-Maron
# Title: Machine Learning Scientist | AI for Drug Discovery | Neuroscience PhD
# Location: Boston, MA
# ---
# Name: Sai Vivek Katkuri
# Title: Machine Learning | MLOps | Gen Ai | NLP | Computer Vision | LLMs | RAG | Ai Agents
# Location: Irving, TX
# ---
# Name: Jae-Woo Choi, Ph.D.
# Title: Machine Learning @ Meta
# Location: Greater Boston
# ---
# Name: Zuraiz Uddin
# Title: Senior Machine Learning Engineer, FinTech, Retail, Healthcare, Computer Vision
# Location: Reston, VA
# ---
# Name: Pratyush Shukla
# Title: Engineer with expertise in Applied AI and R&D. Building the future of autonomous AI.
# Location: San Francisco, CA
# ---
# Name: Tianqi Wang
# Title: Machine Learning at Pinterest
# Location: Greater Seattle Area
# ---
# Name: Shrishailya Chavan
# Title: Ex- Machine Learning Research Engineer at Dassault Systemes | Machine Learning | Generative AI | Deep Learning | Computer Vision | LLM
# Location: United States
# ---
# Name: Drashtee Parmar
# Title: Machine Learning Engineer | AI | Data Scientist | NLP | Deep Learning | MSCS (AI) Graduate @ Kennesaw State University
# Location: Atlanta Metropolitan Area
# ---
# Name: Tan H. Nguyen
# Title: Research Assistant || Machine Learning or Deep Learning for Computer Vision, Natural Language Processing, HCI, and Truth AI
# Location: Pasadena, CA
# ---
# Name: Hasib-Al Rashid
# Title: Applied Scientist @ Amazon Web Services (AWS) || PhD in Computer Engineering, UMBC
# Location: Duluth, GA
# ---
# Name: Awais P.
# Title: Full Stack AI/ML Engineer | Specializing in NLP, Deep Learning, Machine Learning and Computer Vision
# Location: Lititz, PA
# ---
# Name: Mojtaba S.
# Title: Machine Learning | Computer Vision | Gen AI | Data Science | Ex-Novartis | AI in Drug Discovery | Research Scholar@ Harvard | Postdoc scholar@ Stanford
# Location: San Francisco Bay Area
# ---
# Name: Vishwanath Sindagi
# Title: Computer Vision Machine Learning Engineer
# Location: United States
# ---
# Name: Shao-Yuan Lo
# Title: Research Scientist @ Honda Research Institute USA | PhD @ JHU | Trustworthy AI, Machine Learning, Computer Vision
# Location: San Jose, CA
# ---
# Name: Emmanuel Boniface
# Title: Machine Learning Engineer | Data Scientist | AI Innovator
# Location: United States
# ---
# Name: Mohammed Irfan Ali
# Title: Robotics Research @Northeastern University | Perception | Computer Vision | SLAM | Deep learning | Machine Learning
# Location: Boston, MA
# ---
# Name: Neel Dey
# Title: Postdoctoral Researcher @ MIT CSAIL | Machine Learning | Computer Vision | Biomedical Imaging
# Location: Cambridge, MA
# ---

# %%
pd.DataFrame(people)
# Out:
#                                      urn_id    distance  \
# 0   ACoAAAYIxg8BxNB9SLTgtaZAbzzCHTpK4EyIq24  DISTANCE_2
# 1   ACoAAA230BgB8MfL272MJ70ArekRJmEzWPn3SXo  DISTANCE_2
# 2   ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo  DISTANCE_2
# 3   ACoAAC6HuYMB98gOsI0bTuXP8Mb4JAkPgMHFki8  DISTANCE_2
# 4   ACoAADVFoOEBMtMrkmkLajeDpg10gPBma36_AJU  DISTANCE_2
# ..                                      ...         ...
# 95  ACoAAAFdY8MBsQ4jXUX6a_549DCrejf7mqyeeMg  DISTANCE_3
# 96  ACoAACcxrt0B3q8sOSD4z0GU-OEtAn8SxeZ61oc  DISTANCE_3
# 97  ACoAAC7fwDEB8O9A_PdioC5y-YLdR6y7C7omjmI  DISTANCE_3
# 98  ACoAADHxWZ4Bzn6RRCEQQjZgpLDOXWbA8YroYGI  DISTANCE_3
# 99  ACoAAB-RKioBD3nmoHl06JTRA1kwO1H2OQF8mqY  DISTANCE_3
#
#                                              jobtitle             location  \
# 0                Machine Learning | Research Engineer         New York, NY
# 1   A machine learning engineer with scientific tr...         New York, NY
# 2   Data Scientist | Machine Learning | Computer V...  West Palm Beach, FL
# 3                                        AI Scientist         New York, NY
# 4   Machine Learning Engineer | MS 𝗔𝗿𝘁𝗶𝗳𝗶𝗰𝗶𝗮𝗹 𝗜𝗻𝘁𝗲...          Chicago, IL
# ..                                                ...                  ...
# 95          Computer Vision Machine Learning Engineer        United States
# 96  Research Scientist @ Honda Research Institute ...         San Jose, CA
# 97  Machine Learning Engineer | Data Scientist | A...        United States
# 98  Robotics Research @Northeastern University | P...           Boston, MA
# 99  Postdoctoral Researcher @ MIT CSAIL | Machine ...        Cambridge, MA
#
#                              name
# 0                          Lan G.
# 1                  Yeu-Chern Harn
# 2   Mireille P. Feudjio T. (Ph.D)
# 3           Grigorios Karageorgos
# 4               Carlos Muñoz Losa
# ..                            ...
# 95             Vishwanath Sindagi
# 96                   Shao-Yuan Lo
# 97              Emmanuel Boniface
# 98             Mohammed Irfan Ali
# 99                       Neel Dey
#
# [100 rows x 5 columns]

# %%
p0_id = people[0]['urn_id']
p0 = api.get_profile(urn_id=p0_id)

# %%
import json
