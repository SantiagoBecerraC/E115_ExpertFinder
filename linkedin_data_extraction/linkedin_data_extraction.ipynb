# %%
import pandas as pd
import numpy as np
import time
import random
import json
from datetime import datetime

# %%
from linkedin_api import Linkedin

# Authenticate using any Linkedin user account credentials
api = Linkedin('3chamois-bifocal@icloud.com', 'cinnyn-surfix-8Cejji')

# %%
ml_keywords = [
    "machine learning",
    "deep learning", 
    "neural networks",
    "artificial intelligence",
    "natural language processing",
    "computer vision",
    "reinforcement learning",
    "supervised learning",
    "unsupervised learning",
    "convolutional neural networks",
    "recurrent neural networks",
    "transformers",
    "BERT",
    "GPT",
    "feature engineering",
    "data mining",
    "classification",
    "regression",
    "clustering",
    "dimensionality reduction",
    "random forests",
    "gradient boosting",
    "support vector machines",
    "k-means",
    "decision trees",
    "ensemble methods",
    "transfer learning",
    "few-shot learning",
    "zero-shot learning",
    "meta-learning",
    "anomaly detection",
    "time series analysis",
    "recommendation systems",
    "sentiment analysis",
    "text classification",
    "image recognition",
    "object detection",
    "semantic segmentation",
    "generative models",
    "GANs",
    "autoencoders",
    "LSTM",
    "attention mechanism",
    "hyperparameter tuning",
    "cross-validation",
    "regularization",
    "dropout",
    "batch normalization",
    "optimization",
    "gradient descent",
    "backpropagation",
    "loss functions",
    "activation functions",
    "tensorflow",
    "pytorch",
    "keras",
    "scikit-learn",
    "pandas",
    "numpy",
    "data preprocessing",
    "feature selection",
    "model evaluation",
    "confusion matrix",
    "ROC curve",
    "precision-recall",
    "F1 score",
    "accuracy",
    "bias-variance tradeoff",
    "overfitting",
    "underfitting",
    "data augmentation",
    "model deployment",
    "MLOps",
    "model monitoring",
    "A/B testing",
    "data visualization",
    "exploratory data analysis",
    "data cleaning",
    "data labeling",
    "model interpretability",
    "explainable AI",
    "ethical AI",
    "responsible AI",
    "federated learning",
    "distributed training",
    "quantum machine learning",
    "edge AI",
    "AutoML",
    "neural architecture search",
    "knowledge distillation",
    "domain adaptation",
    "self-supervised learning",
    "semi-supervised learning",
    "active learning",
    "online learning",
    "incremental learning",
    "multi-task learning",
    "multi-modal learning",
    "graph neural networks",
    "probabilistic modeling",
    "bayesian inference",
    "causal inference",
    "reinforcement learning",
    "imitation learning",
    "curriculum learning",
    "adversarial training",
    "model compression",
    "quantization",
    "pruning"
]

ml_keywords = ml_keywords[:5]

# %% [markdown]
# `search_people` method:
# - keywords (str, optional) – Keywords to search on
# - current_company (list, optional) – A list of company URN IDs (str)
# - past_companies (list, optional) – A list of company URN IDs (str)
# - regions (list, optional) – A list of geo URN IDs (str)
# - industries (list, optional) – A list of industry URN IDs (str)
# - schools (list, optional) – A list of school URN IDs (str)
# - profile_languages (list, optional) – A list of 2-letter language codes (str)
# - contact_interests (list, optional) – A list containing one or both of “proBono” and “boardMember”
# - service_categories (list, optional) – A list of service category URN IDs (str)
# - network_depth (str, optional) – Deprecated, use network_depths. One of “F”, “S” and “O” (first, second and third+ respectively)
# - network_depths (list, optional) – A list containing one or many of “F”, “S” and “O” (first, second and third+
# respectively)
# - include_private_profiles (boolean, optional) – Include private profiles in search results. If False, only public profiles are included. Defaults to False
# - keyword_first_name (str, optional) – First name
# - keyword_last_name (str, optional) – Last name
# - keyword_title (str, optional) – Job title
# - keyword_company (str, optional) – Company name
# - keyword_school (str, optional) – School name
# - connection_of (str, optional) – Connection of LinkedIn user, given by profile URN ID
# - limit (int, optional) – Maximum length of the returned list, defaults to -1 (no limit)

# %%
# Create a timestamp for the file naming
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# Iterate through pairs of keywords
for i in range(len(ml_keywords) - 1):
    # Get current pair of keywords
    keyword_pair = f"{ml_keywords[i]} {ml_keywords[i+1]}"
    print(f"Searching for: {keyword_pair}")
    
    try:
        # Random delay between 3-7 seconds to avoid rate limiting
        delay = random.uniform(3, 7)
        time.sleep(delay)
        
        # Search for people with the keyword pair
        people = api1.search_people(
            keywords=keyword_pair,
            regions=['103644278'],  # Keeping your original region
            limit=100
        )
        
        # Save the results immediately
        filename = f"data/keyword_searches/search_{timestamp}_pair_{i}.json"
        results = {
            'keywords': keyword_pair,
            'timestamp': datetime.now().isoformat(),
            'results': people
        }
        
        with open(filename, "w", encoding="utf-8") as f:
            json.dump(results, f, indent=4, ensure_ascii=False)
            
        print(f"Saved {len(people)} results for pair {i}")
        
    except Exception as e:
        print(f"Error occurred with keyword pair {i}: {keyword_pair}")
        print(f"Error message: {str(e)}")
        # Save the error information
        error_filename = f"data/keyword_searches/errors_{timestamp}.txt"
        with open(error_filename, "a", encoding="utf-8") as f:
            f.write(f"Error at pair {i} ({keyword_pair}): {str(e)}\n")
# Out:
# Searching for: machine learning deep learning
# Saved 72 results for pair 0
# Searching for: deep learning neural networks
# Saved 67 results for pair 1
# Searching for: neural networks artificial intelligence
# Saved 58 results for pair 2
# Searching for: artificial intelligence natural language processing
# Saved 58 results for pair 3

# %%
len(people1)
# Out:
# 72

# %%
len(people)
# Out:
# 100

# %%
for person in people:
    print(f"Name: {person['name']}")
    print(f"Title: {person['jobtitle']}")
    print(f"Location: {person['location']}")
    print("---")
# Out:
# Name: Raul Molina
# Title: Machine Learning Engineer
# Location: San Francisco, CA
# ---
# Name: Lan G.
# Title: Machine Learning | Research Engineer
# Location: New York, NY
# ---
# Name: Ziqi Ke
# Title: Senior Machine Learning Engineer @ Bloomberg AI
# Location: New York, NY
# ---
# Name: Julian E. Gomez
# Title: Oil & Gas | Artificial Intelligence | NLP | Machine learning | Reinforcement learning | Genetic Algorithms | Deep neural networks | Data Science | Semantic Web | Mobile Development
# Location: United States
# ---
# Name: German Garcia Jara
# Title: Machine Learning Engineer @ LinkedIn
# Location: San Francisco, CA
# ---
# Name: Felipe Ramirez
# Title: Machine Learning Manager @ Tailored Brands, Inc. | PhD
# Location: San Diego, CA
# ---
# Name: Santiago Bolaños Vega
# Title: Information Systems Management @ CMU | AI | Machine Learning | Data Science | Data Engineering | IT Strategy
# Location: Pittsburgh, PA
# ---
# Name: Omar Leonardo Sanchez Granados
# Title: Sr Data Engineer @ Keystone Strategy | CMU alumni
# Location: Boston, MA
# ---
# Name: Santiago Cortes
# Title: Machine Learning PhD Student at Carnegie Mellon University
# Location: Pittsburgh, PA
# ---
# Name: Carlos Muñoz Losa
# Title: Machine Learning Engineer | MS 𝗔𝗿𝘁𝗶𝗳𝗶𝗰𝗶𝗮𝗹 𝗜𝗻𝘁𝗲𝗹𝗹𝗶𝗴𝗲𝗻𝗰𝗲 | Telecommunications Engineer | Soccer Coach | Student Athlete
# Location: Chicago, IL
# ---
# Name: Yeu-Chern Harn
# Title: A machine learning engineer with scientific training, and with experience building computer vision ML products from the ground-up.
# Location: New York, NY
# ---
# Name: Teodor Georgiev
# Title: Machine Learning at Haystack News
# Location: Miami-Fort Lauderdale Area
# ---
# Name: Gonzalo Garcia
# Title: Machine Learning Engineer @ Dropbox
# Location: Seattle, WA
# ---
# Name: Esteban Correa
# Title: Machine Learning | AI in Precision Medicine | Healthcare | Electronic Health Records
# Location: Cincinnati, OH
# ---
# Name: Felipe Montealegre-Mora
# Title: UC Berkeley, Ecology - Machine Learning - Quantum Computing
# Location: Emeryville, CA
# ---
# Name: Kalyan Mupparaju
# Title: Data Scientist | Machine Learning | Deep Learning
# Location: Middlesex, NJ
# ---
# Name: Richard Rivas
# Title: Data Scientist at the World Bank Group (IFC) | MSc in Business Analytics | Machine Learning | Natural Language Processing
# Location: Washington, DC
# ---
# Name: Matt Ryerkerk
# Title: Software Engineer at Bloomberg LP (Machine Learning Platform)
# Location: Jersey City, NJ
# ---
# Name: Raghu Y.
# Title: Machine Learning Researcher | Explainable AI Advocate | Poet | Topology Dilettante
# Location: Rolla, MO
# ---
# Name: Juan Sebastián Hernández Gómez
# Title: MS in AI @CMU | Product Management | Machine Learning | Data Science
# Location: Pittsburgh, PA
# ---
# Name: Crispin Vincent Lobo
# Title: Principal Data Scientist at Capital One | MS Honors at Columbia University | Data Science | Machine Learning | Deep Learning | AI
# Location: New York, NY
# ---
# Name: Pranav Karnani
# Title: Data Scientist - JP Morgan Chase | Machine Learning Engineer | Deep Learning | Natural Language Processing | Carnegie Mellon Graduate
# Location: New York City Metropolitan Area
# ---
# Name: Jennifer C.
# Title: Deep Learning @ NVIDIA | Columbia BA & MS
# Location: New York, NY
# ---
# Name: Brian Pennisi, CFA
# Title: Machine Learning Engineer @ Meta
# Location: New York City Metropolitan Area
# ---
# Name: Gonzalo Moreno
# Title: Data Scientist, Generative AI, NLP, LLM, MLOPS, Deep Learning, Machine Learning. AI Orchestration & Integration
# Location: Miami Beach, FL
# ---
# Name: Lina Gomez
# Title: Data Scientist - MIT | Machine Learning | Business Analyst | M.A. in Economics | Data Analyst | Data-Driven Decision Maker | Storyteller | Python | PowerBI | SQL | ML | Data is my passion
# Location: New York, NY
# ---
# Name: Kamil Krukowski
# Title: Machine Learning Engineer | Building Big Models to Solve Big Problems
# Location: Somerville, MA
# ---
# Name: Sean Cantrell
# Title: Senior Machine Learning Engineer at Spotify
# Location: Brooklyn, NY
# ---
# Name: Sara Afshar
# Title: Data scientist | ML Engineer | Data Engineer
# Location: United States
# ---
# Name: William Moreno Herbas
# Title: IT Manager | Data Scientist | AI Machine Learning & Deep Learning | Master Big Data & Business Analytics | Python Django Developer
# Location: Lewisville, TX
# ---
# Name: Jose Gabriel Navarro De La Cruz
# Title: PhD. Student || Data Scientist || Machine/Deep Learning || Supply Chain || Optimization
# Location: Tampa, FL
# ---
# Name: Madhavan Seshadri
# Title: Team Lead, Machine Learning at Bloomberg LP
# Location: New York, NY
# ---
# Name: Pourya Rezaee
# Title: Senior Biomedical Data Scientist | Machine Learning | Deep Learning | Python
# Location: Los Altos, CA
# ---
# Name: Raymond(Haimin) Zhang
# Title: Staff Machine Learning Engineer at Facebook
# Location: United States
# ---
# Name: Jhon Harry Loaiza
# Title: Data Scientist | Machine Learning Engineer | AI
# Location: New York City Metropolitan Area
# ---
# Name: Daniel Lopez-Castano
# Title: PhD candidate at Johns Hopkins University | Applied Mathematician | Machine Learning Researcher | Fulbright Scholar
# Location: Baltimore, MD
# ---
# Name: Melis Özyıldırım
# Title: Machine Learning Engineer at Apple
# Location: United States
# ---
# Name: Sibel Sezen
# Title: Data Science | Machine Learning | Deep Learning | Data Analytics | Python
# Location: Westchester County, NY
# ---
# Name: Juan Sebastián Salcedo Gallo
# Title: Quantum Computing Engineering | Machine Learning | PhD Student @ Dartmouth College
# Location: Hanover, NH
# ---
# Name: Zeqi Mao
# Title: Machine Learning Engineer @ Bloomberg LP | Master of Science in Statistics
# Location: New York, NY
# ---
# Name: Mireille P. Feudjio T. (Ph.D)
# Title: Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life
# Location: West Palm Beach, FL
# ---
# Name: Jeremy Mathew
# Title: Passionate Data Scientist | Data Engineer | Turning Data into Insights | Machine Learning | Data Analysis & Visualization
# Location: New York City Metropolitan Area
# ---
# Name: Priyanka Gonugunta
# Title: Senior Data Scientist @ Data Labs - LANDMARK GROUP | Data Analytics, Business Intelligence
# Location: St Louis, MO
# ---
# Name: Yanet Fernandez
# Title: Data Analyst & Scientist | SQL, Python, Cloud Technologies | Passionate about AI & Machine Learning
# Location: Miami, FL
# ---
# Name: Yash Madhukar Patil
# Title: Data Scientist | Machine Learning | NLP | Deep Learning | AI & Cloud Solutions (AWS, Azure) | Predictive Analytics | Big Data
# Location: United States
# ---
# Name: Pedro Alejandro Bestard Hernández
# Title: Sr Data Scientist | NLP Techniques, Predictive Modeling, Statistical Inference, User Segmentation
# Location: Miami, FL
# ---
# Name: Rohan Ramanath
# Title: AI Product & Machine Learning Engineering
# Location: United States
# ---
# Name: Sweekruthi Balivada
# Title: Machine Learning, Deep Learning and AI enthusiast | Data Engineering | Oracle Gen AI certified | Applied Data Science @ SJSU | Ex-Infosys
# Location: San Jose, CA
# ---
# Name: Eyal Wirsansky
# Title: Senior Data Scientist | AI Specialist | Author of 'Hands-On Genetic Algorithms with Python' | Innovator in Machine Learning and Scalable Cloud Solutions | Community Leader & Educator
# Location: Jacksonville, FL
# ---
# Name: Venu Chaudhari
# Title: MSCS @UCSD | Machine Learning | Deep Learning | Data Science
# Location: San Diego, CA
# ---
# Name: Paul Knysh
# Title: Senior Machine Learning Engineer at Harbinger Health
# Location: Boston, MA
# ---
# Name: Rhetta Hsu
# Title: Experienced Data Analyst | Data Scientist | MS Business Analytics at Boston University | Data Analysis | Machine Learning | Data Believer
# Location: Boston, MA
# ---
# Name: Sanket Desai
# Title: Machine Learning | Deep Learning | Reinforcement Learning | LLM. Interested in AI Research and Diffusion Models.
# Location: New York City Metropolitan Area
# ---
# Name: Henry Ruiz, Ph.D
# Title: Research Scientist @ Texas A&M University | AgriLife Research | AI, Machine Learning, Deep Learning
# Location: College Station, TX
# ---
# Name: Thomas Pellet
# Title: Data Science & Technology @ Bloomberg | Macroeconomics | Machine Learning | Cheese amateur
# Location: New York, NY
# ---
# Name: Arturo Polanco Lozano
# Title: Machine Learning Engineer | AI Research Finance
# Location: Madison, WI
# ---
# Name: David Boe
# Title: Machine Learning | Neuroscience | Hard Problems
# Location: Greater Seattle Area
# ---
# Name: Harsh Verma
# Title: Data Science and ML Leader || Machine/Deep Learning | Analytics
# Location: New York, NY
# ---
# Name: Bindu Basupalli
# Title: Data Scientist | Machine Learning, Deep Learning, NLP | Python, R, SQL | AWS, Azure, GCP | Data Automation & Real-Time Processing | Tableau, Power BI | Driving Innovation in E-Commerce & Finance
# Location: United States
# ---
# Name: Amit Modi
# Title: AI/ML Architect | Generative AI & LLMOps | Building Scalable AI for the Enterprise
# Location: United States
# ---
# Name: Asa Barth-Maron
# Title: Machine Learning Scientist | AI for Drug Discovery | Neuroscience PhD
# Location: Boston, MA
# ---
# Name: Siddhant Gupta
# Title: Data Scientist @ LexisNexis | NLP, Machine Learning, SageMaker
# Location: Raleigh, NC
# ---
# Name: Abhilash Maspalli Srinivas
# Title: Data Scientist at USAA | MSBA at UTD | Machine Learning | NLP | Deep Learning
# Location: Dallas-Fort Worth Metroplex
# ---
# Name: Leonardo Talero
# Title: Senior Data Scientist | Expert in AI & Machine Learning | Transforming Data into Business Insights
# Location: San Francisco, CA
# ---
# Name: Tianqi Wang
# Title: Machine Learning at Pinterest
# Location: Greater Seattle Area
# ---
# Name: Mike Powell
# Title: Medical AI Scientist / Engineer
# Location: United States
# ---
# Name: Rishi More
# Title: CS @JHU | Computer Science | Machine Learning | Deep Learning
# Location: Baltimore, MD
# ---
# Name: Ramesh Gundeti
# Title: Director, Software Engineering | Machine Learning/Deep Learning | ML Ops
# Location: Atlanta, GA
# ---
# Name: Joshua Chung
# Title: Data Scientist
# Location: San Francisco, CA
# ---
# Name: Etai Littwin
# Title: Senior Deep Learning Research Scientist at Apple
# Location: United States
# ---
# Name: Matthew B.
# Title: Data Scientist (MSDS) | Power BI, Qlik Sense, Tableau, SQL, Databricks, Python, R, ETL & Machine Learning Specialist | 6 Years in Gov't & Private Sector | Business Intelligence & Advanced Analytics
# Location: Tampa, FL
# ---
# Name: Jack Brubaker
# Title: Artificial Intelligence | Machine Learning | Deep Learning | HPC
# Location: Raleigh, NC
# ---
# Name: Steven Parra
# Title: Artificial Intelligence Specialist | Deep Learning | Computer Vision | Machine Learning
# Location: Miami, FL
# ---
# Name: Rashid khazeiynasab
# Title: Data Scientist/Machine Learning Engineer at Oracle
# Location: United States
# ---
# Name: Linah Rusere , PhD
# Title: Scientist | Data Analyst
# Location: United States
# ---
# Name: Nikunj Malpani
# Title: Data Scientist @ CVS | Ex- Amazon | Data Science, Machine Learning | AWS Cloud Practioner
# Location: New York, NY
# ---
# Name: Aditya Jasuja
# Title: Actively looking for data scientist opportunities | Data Science | Machine Learning | Deep Learning | GenAI | LLM | Product |
# Location: San Francisco Bay Area
# ---
# Name: Mohammad Rifat Ullah
# Title: Machine Learning; Deep Learning; Researcher, and a Future Scientist
# Location: Indianapolis, IN
# ---
# Name: Shrinivas Gollalappa K
# Title: Data Scientist | Generative AI | Deep Learning & Machine Learning Expert | Seeking New Opportunities in AI & Innovation
# Location: United States
# ---
# Name: Hariprasad Reddy Marri
# Title: Data Science Engineer | MS in Data Science @NJIT | Machine Learning | Deep Learning | Data Analytics
# Location: New York City Metropolitan Area
# ---
# Name: Naresh Doni Jayavelu
# Title: Translational Bioinformatics | Computational Biology | Next-generation sequencing (NGS) | Data Science | Machine Learning | Deep learning | Seattle
# Location: Seattle, WA
# ---
# Name: Khaled ElAdl
# Title: Founder and Python Developer with expertise in Machine Learning and Deep Learning
# Location: Greater Houston
# ---
# Name: Rohit Rajkumar Dhonukshe
# Title: Data Scientist | Python, R, SQL | Machine Learning | Deep Learning | Statistics & Econometrics | Data Analytics | E-commerce | Ads | Marketing | MS in Data Science
# Location: Brooklyn, NY
# ---
# Name: Shivani Chauhan
# Title: MS Data Science @ ASU | Data Science | Artificial Intelligence | Machine Learning | Data Analytics | Deep Learning
# Location: Tempe, AZ
# ---
# Name: Bahador Bahmani, PhD
# Title: Postdoctoral Research Fellow @ JHU | Scientific Machine Learning
# Location: United States
# ---
# Name: Bryan 🛸 Sagredo
# Title: Machine Learning Engineer 🤖
# Location: Seattle, WA
# ---
# Name: Raj Shah
# Title: AI Engineer | AI & Data Enthusiast | Machine Learning | Deep Learning | Analytics | Eager to Learn & Contribute | Master's in AI (Illinois Tech)
# Location: Los Angeles Metropolitan Area
# ---
# Name: Ankush Israney
# Title: Machine Learning at Walmart
# Location: Princeton, NJ
# ---
# Name: Shrishailya Chavan
# Title: Ex- Machine Learning Research Engineer at Dassault Systemes | Machine Learning | Generative AI | Deep Learning | Computer Vision | LLM
# Location: United States
# ---
# Name: Issac Kondreddy
# Title: Open to Work | Data Scientist | Machine Learning Engineer | Python, Machine Learning, Deep Learning, SQL |
# Location: Cookeville, TN
# ---
# Name: Daniel de Roux
# Title: Research data scientist at Google. Recently I obtained my PhD in Algorithms, Combinatorics and Optimization at Carnegie Mellon University.
# Location: Pittsburgh, PA
# ---
# Name: Emilio Volpe
# Title: Senior Machine Learning Engineer
# Location: Los Altos, CA
# ---
# Name: Yotam Hechtlinger
# Title: CEO & Founder of Exists | Ph.D. in Machine Learning & Statistics, Carnegie Mellon University
# Location: United States
# ---
# Name: Nikhil Thota
# Title: Machine Learning R&D at AMD
# Location: Austin, TX
# ---
# Name: Michael Gates
# Title: Media & Entertainment | Deep Learning & Machine Learning | XR |
# Location: Costa Mesa, CA
# ---
# Name: Prem Kumar Rasakonda
# Title: Machine Learning Lead at Cynthia Robotics | ML & Data Science Engineer
# Location: United States
# ---
# Name: Brendan Fahy
# Title: AI - Staff Engineer
# Location: New York, NY
# ---
# Name: Simon Sebbagh
# Title: AI & Machine Learning | Ex JPMorgan | Harvard MS
# Location: New York, NY
# ---
# Name: Jimena González
# Title: Physicist | Data Sciencist | Machine Learning Engineer | Software Developer
# Location: Madison, WI
# ---
# Name: Rojan Shrestha
# Title: Computational Protein Engineer and Machine Learning
# Location: Watertown, MA
# ---

# %%
pd.DataFrame(people)
# Out:
#                                      urn_id    distance  \
# 0   ACoAACHYtlkBRQgLOg5mzySuXB8_n8cvWfE3X5U  DISTANCE_2
# 1   ACoAAAYIxg8BxNB9SLTgtaZAbzzCHTpK4EyIq24  DISTANCE_2
# 2   ACoAAB-hYWgBDpfCl0olhxXUgKs0ZHxj2WDCJl0  DISTANCE_2
# 3   ACoAAA7NiZkBjUrb1xYaNfMxEcWLm7uI9imMTbI  DISTANCE_2
# 4   ACoAACNXZCYBrBi-b_Yg_cEgL0sdNhk0TwW5Tr4  DISTANCE_2
# ..                                      ...         ...
# 95  ACoAACnUovABmsmmwryY7Wm_A0eFtXdGqtHX0VU  DISTANCE_3
# 96  ACoAABpHD4gBo__cVTeoCKSwWfJcBu3BWsDZiQI  DISTANCE_2
# 97  ACoAABobw_8Br0bRsnwsz9D3DG-l-SVo17UNLpg  DISTANCE_2
# 98  ACoAAA1Mmp8BFua-I9dx7Hjq_P5lcrGTvZ0yn_k  DISTANCE_2
# 99  ACoAAAjCXk8BJcdbnXyXW30iP9bokOLF9mAGTH4  DISTANCE_2
#
#                                              jobtitle           location  \
# 0                           Machine Learning Engineer  San Francisco, CA
# 1                Machine Learning | Research Engineer       New York, NY
# 2     Senior Machine Learning Engineer @ Bloomberg AI       New York, NY
# 3   Oil & Gas | Artificial Intelligence | NLP | Ma...      United States
# 4                Machine Learning Engineer @ LinkedIn  San Francisco, CA
# ..                                                ...                ...
# 95  Machine Learning Lead at Cynthia Robotics | ML...      United States
# 96                                AI - Staff Engineer       New York, NY
# 97   AI & Machine Learning | Ex JPMorgan | Harvard MS       New York, NY
# 98  Physicist | Data Sciencist | Machine Learning ...        Madison, WI
# 99  Computational Protein Engineer and Machine Lea...      Watertown, MA
#
#                     name
# 0            Raul Molina
# 1                 Lan G.
# 2                Ziqi Ke
# 3        Julian E. Gomez
# 4     German Garcia Jara
# ..                   ...
# 95  Prem Kumar Rasakonda
# 96          Brendan Fahy
# 97         Simon Sebbagh
# 98       Jimena González
# 99        Rojan Shrestha
#
# [100 rows x 5 columns]

# %%
# p0_id = people[0]['urn_id']
# p0 = api.get_profile(urn_id=p0_id)

import time
import random
import json

# Get profiles for first 10 people and save to JSON
for i, person in enumerate(people[:10]):
    # Random delay between 2-5 seconds
    delay = random.uniform(2, 5)
    time.sleep(delay)
    
    profile = api1.get_profile(urn_id=person['urn_id'])
    
    filename = f"data/profiles/profile_{i}.json"
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(profile, f, indent=4, ensure_ascii=False)

# %%
import json

with open("p0.json", "w", encoding="utf-8") as f:
    json.dump(p0, f, indent=4, ensure_ascii=False)

# %%
p0_contact = api.get_profile_contact_info(urn_id=p0_id)
p0_contact
# Out:
# {'email_address': None,
#  'websites': [],
#  'twitter': [],
#  'birthdate': None,
#  'ims': None,
#  'phone_numbers': []}

# %%
p0_exp = api.get_profile_experiences(urn_id=p0_id)
p0_exp
# Out:
# [{'title': 'Senior Vice President',
#   'companyName': 'Full-time',
#   'employmentType': None,
#   'locationName': 'New York',
#   'duration': '1 yr',
#   'startDate': '2020',
#   'endDate': '2021',
#   'description': '- Recruited/trained a team of quantitative developers maintaining a library of multi-asset class models for counterparty credit risk exposure calculation; oversaw people management and technical leadership.\n- Established development and continuous integration processes to scale across the team.\n- Co-piloted cross-team initiatives to standardize and decentralize model library development.\n- Seeded work on a new library for economic scenario generation to improve efficiency of model implementation.'},
#  {'title': 'Vice President',
#   'companyName': None,
#   'employmentType': None,
#   'locationName': 'New York',
#   'duration': '5 yrs',
#   'startDate': '2015',
#   'endDate': '2020',
#   'description': '- Developed models for interest rate (IR) and foreign exchange (FX) derivatives for exchange and OTC markets to provide counterparty risk exposure estimation.\n- Built deep learning models for time series and benchmarked performance with common baselines.'},
#  {'title': 'Assistant Vice President',
#   'companyName': None,
#   'employmentType': None,
#   'locationName': 'New York, New York',
#   'duration': '2 yrs',
#   'startDate': '2013',
#   'endDate': '2015',
#   'description': '- Modeled default of credit issuers using multi-factor Monte-Carlo simulation for Federal Reserve’s stress testing.\n- Migrated model code from Python to Cython (C-Extensions for Python) and improved runtime by 75%.'}]

# %%
p0_network = api.get_profile_network_info('lan-gong')
p0_network
# Out:
# {'distance': {'value': 'DISTANCE_2',
#   '$type': 'com.linkedin.voyager.common.MemberDistance'},
#  'entityUrn': 'urn:li:fs_profileNetworkInfo:ACoAAAYIxg8BxNB9SLTgtaZAbzzCHTpK4EyIq24',
#  'following': False,
#  'followable': True,
#  '*followingInfo': 'urn:li:fs_followingInfo:urn:li:member:ACoAAAYIxg8BxNB9SLTgtaZAbzzCHTpK4EyIq24',
#  'followersCount': 641,
#  'connectionsCount': 500,
#  '$type': 'com.linkedin.voyager.identity.profile.ProfileNetworkInfo'}

# %%
p0_posts = api.get_profile_posts(urn_id=p0_id)
with open("p0_posts.json", "w", encoding="utf-8") as f:
    json.dump(p0_posts, f, indent=4, ensure_ascii=False)

p0_posts
# Out:
# [{'actor': {'urn': 'urn:li:member:177141167',
#    'image': {'accessibilityTextAttributes': [],
#     'attributes': [{'sourceType': 'PROFILE_PICTURE',
#       'miniProfile': {'firstName': 'Donny',
#        'lastName': 'Greenberg',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAqO9a8B86XfJPr3hllJszDbjrkWvQY6HYM',
#        'occupation': 'CEO at 🏃\u200d♀️Runhouse🏠, x-PyTorch',
#        'objectUrn': 'urn:li:member:177141167',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAAqO9a8B86XfJPr3hllJszDbjrkWvQY6HYM',
#        'publicIdentifier': 'greenbergdon',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1652171682812?e=1745452800&v=beta&t=HC_NfkLaTsYoDQDOM1tGkiA2pabmzs3motbsH-M8w2s',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1652171682812?e=1745452800&v=beta&t=fgZRIH0MaVFsGYnx06usYJ8JV2dHR2DaW7VVa-AGCW0',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 346,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1652171682812?e=1745452800&v=beta&t=a_uI_qdTV341mx6rvfoL4-SWhCctHL2-HmRwqbjD9m8',
#            'expiresAt': 1745452800000,
#            'height': 346},
#           {'width': 346,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1652171682812?e=1745452800&v=beta&t=ThoZa0Iv3soJK8pAX61085wbpS_UUu9Rf5QZ0hXaCdw',
#            'expiresAt': 1745452800000,
#            'height': 346}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4E03AQE4LLvvkpAZQQ/profile-displayphoto-shrink_'}},
#        'trackingId': 'iQbT9oVPRcWKZrXz+0KvmQ=='}}]},
#    'supplementaryActorInfo': {'textDirection': 'USER_LOCALE',
#     'accessibilityText': ' • 2nd',
#     'text': ' • 2nd'},
#    'name': {'textDirection': 'FIRST_STRONG',
#     'attributes': [{'start': 0,
#       'length': 15,
#       'miniProfile': {'firstName': 'Donny',
#        'lastName': 'Greenberg',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAqO9a8B86XfJPr3hllJszDbjrkWvQY6HYM',
#        'occupation': 'CEO at 🏃\u200d♀️Runhouse🏠, x-PyTorch',
#        'objectUrn': 'urn:li:member:177141167',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAAqO9a8B86XfJPr3hllJszDbjrkWvQY6HYM',
#        'publicIdentifier': 'greenbergdon',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1652171682812?e=1745452800&v=beta&t=HC_NfkLaTsYoDQDOM1tGkiA2pabmzs3motbsH-M8w2s',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1652171682812?e=1745452800&v=beta&t=fgZRIH0MaVFsGYnx06usYJ8JV2dHR2DaW7VVa-AGCW0',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 346,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1652171682812?e=1745452800&v=beta&t=a_uI_qdTV341mx6rvfoL4-SWhCctHL2-HmRwqbjD9m8',
#            'expiresAt': 1745452800000,
#            'height': 346},
#           {'width': 346,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1652171682812?e=1745452800&v=beta&t=ThoZa0Iv3soJK8pAX61085wbpS_UUu9Rf5QZ0hXaCdw',
#            'expiresAt': 1745452800000,
#            'height': 346}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4E03AQE4LLvvkpAZQQ/profile-displayphoto-shrink_'}},
#        'trackingId': 'iQbT9oVPRcWKZrXz+0KvmQ=='},
#       'type': 'PROFILE_FULLNAME'}],
#     'text': 'Donny Greenberg',
#     'accessibilityText': 'Donny Greenberg'},
#    'subDescription': {'textDirection': 'USER_LOCALE',
#     'attributes': [{'start': 6,
#       'length': 1,
#       'artDecoIcon': 'IC_GLOBE_16DP',
#       'type': 'ART_DECO_ICON'}],
#     'text': '1yr •   ',
#     'accessibilityText': '1 year ago'},
#    'navigationContext': {'trackingActionType': 'viewAttributedMember',
#     'accessibilityText': 'View Donny Greenberg’s profile',
#     'actionTarget': 'https://www.linkedin.com/in/greenbergdon?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAqO9a8B86XfJPr3hllJszDbjrkWvQY6HYM'},
#    'description': {'textDirection': 'USER_LOCALE',
#     'accessibilityText': 'CEO at 🏃\u200d♀️Runhouse🏠, x-PyTorch',
#     'text': 'CEO at 🏃\u200d♀️Runhouse🏠, x-PyTorch'},
#    'followAction': {'followTrackingActionType': 'followMember',
#     'followingInfo': {'followingType': 'DEFAULT',
#      'entityUrn': 'urn:li:fs_followingInfo:urn:li:member:ACoAAAqO9a8B86XfJPr3hllJszDbjrkWvQY6HYM',
#      'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_profile:ACoAAAqO9a8B86XfJPr3hllJszDbjrkWvQY6HYM',
#      'following': False,
#      'trackingUrn': 'urn:li:member:177141167'},
#     'unfollowTrackingActionType': 'unfollowMember',
#     'type': 'FOLLOW_TOGGLE',
#     'trackingActionType': 'followMember'}},
#   'dashEntityUrn': 'urn:li:fsd_update:(urn:li:activity:7115868155998007296,MEMBER_SHARES,EMPTY,DEFAULT,false)',
#   'updateMetadata': {'urn': 'urn:li:activity:7115580246564720640',
#    'actionsPosition': 'HEADER_COMPONENT',
#    'updateActions': {'actions': [{'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_BOOKMARK_OUTLINE_MEDIUM'}]},
#       'actionType': 'SAVE',
#       'saveAction': {'entityUrn': 'urn:li:fs_saveAction:(SAVE,urn:li:activity:7115580246564720640)',
#        'saved': False,
#        'dashEntityUrn': 'urn:li:fsd_saveState:(SAVE,urn:li:activity:7115580246564720640)'},
#       'text': 'Save'},
#      {'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_LINK_MEDIUM'}]},
#       'actionType': 'SHARE_VIA',
#       'text': 'Copy link to post',
#       'url': 'https://www.linkedin.com/feed/update/urn:li:activity:7115580246564720640?utm_source=share&utm_medium=member_desktop&rcm=ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk'},
#      {'actionType': 'REPORT',
#       'targetUrn': 'urn:li:share:7115580245872631808',
#       'contentSource': 'UGC_POST',
#       'authorProfileId': 'ACoAAAqO9a8B86XfJPr3hllJszDbjrkWvQY6HYM',
#       'authorUrn': 'urn:li:member:177141167',
#       'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_REPORT_MEDIUM'}]},
#       'secondaryAction': {'icon': {'accessibilityTextAttributes': [],
#         'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#           'systemImage': 'SYS_ICN_VISIBILITY_OFF_MEDIUM'}]},
#        'actionType': 'HIDE_UPDATE',
#        'targetUrn': 'urn:li:activity:7115868155998007296',
#        'text': 'Hide this post',
#        'confirmationAction': {'title': {'textDirection': 'USER_LOCALE',
#          'text': 'Post removed'},
#         'description': {'textDirection': 'USER_LOCALE',
#          'text': "You'll no longer see this post in your feed."},
#         'undoable': True}},
#       'text': 'Report post',
#       'confirmationAction': {'title': {'textDirection': 'USER_LOCALE',
#         'text': 'Thank you for your report'},
#        'description': {'textDirection': 'USER_LOCALE',
#         'text': 'We appreciate you letting us know'},
#        'undoable': False}}],
#     'entityUrn': 'urn:li:fs_updateV2Actions:(urn:li:activity:7115580246564720640,MEMBER_SHARES,EMPTY,-,-)',
#     'dashEntityUrn': 'urn:li:fsd_updateActions:(urn:li:activity:7115580246564720640,MEMBER_SHARES,EMPTY,urn:li:reason:-,urn:li:adCreative:-)'},
#    'actionTriggerEnabled': False,
#    'detailPageType': 'FEED_DETAIL',
#    'shareAudience': 'PUBLIC',
#    'shareUrn': 'urn:li:share:7115580245872631808',
#    'excludedFromSeen': False,
#    'rootShare': True,
#    'trackingData': {'requestId': '6de9a772-ac8e-485d-9a52-d1f2ee2791bf',
#     'trackingId': 'oRXVfiURliJUdCi+BlpqXg=='}},
#   'socialContent': {'updateSaveActionToolTipLegoTrackingToken': '...',
#    'shareUrl': 'https://www.linkedin.com/posts/greenbergdon_packaging-hell-is-dragging-ml-share-7115580245872631808-SG0T?utm_source=combined_share_message&utm_medium=member_desktop&rcm=ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk'},
#   'entityUrn': 'urn:li:fs_updateV2:(urn:li:activity:7115868155998007296,MEMBER_SHARES,EMPTY,DEFAULT,false)',
#   'header': {'image': {'accessibilityTextAttributes': [],
#     'accessibilityText': 'Lan’s profile photo',
#     'attributes': [{'sourceType': 'PROFILE_PICTURE',
#       'miniProfile': {'firstName': 'Lan',
#        'lastName': 'G.',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAYIxg8BxNB9SLTgtaZAbzzCHTpK4EyIq24',
#        'occupation': 'Machine Learning | Research Engineer',
#        'objectUrn': 'urn:li:member:101238287',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAAYIxg8BxNB9SLTgtaZAbzzCHTpK4EyIq24',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1676568011762?e=1745452800&v=beta&t=dzc74zsEfv_F20sJMtMbxzCl9q2htxAgGqL-3iDujyY',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 1400,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1676568011762?e=1745452800&v=beta&t=f19j9ycY8m3wt6tiosqKkNTi2H-O0CGUBJs80WC1wmA',
#            'expiresAt': 1745452800000,
#            'height': 350}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/D4E16AQHcL0EcRVVeJg/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'lan-gong',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1581190098755?e=1745452800&v=beta&t=tso5ihBpFHKWbD1K_xIzRFIMy_3IMtVm2pWxFdTnXwY',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1581190098726?e=1745452800&v=beta&t=_HXcXdcH9RKylK8op4cqXZQTnF6aPouomnjmtYErMQg',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1581190098795?e=1745452800&v=beta&t=fSSmDtuoQtbEY4scDst5ry1Gs0g5XCWHF__xi8b4T8o',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1581190098838?e=1745452800&v=beta&t=TdLnpU4Iwpv1sMIcunmZVoDuykRgvvjMMG7CfENhrb8',
#            'expiresAt': 1745452800000,
#            'height': 800}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4E03AQE-BYC1Qpv__A/profile-displayphoto-shrink_'}},
#        'trackingId': 'ahikusFOQzyIgwhB+ciAig=='}}]},
#    'navigationContext': {'trackingActionType': 'viewUpdateDetail',
#     'accessibilityText': 'View full post',
#     'actionTarget': 'https://www.linkedin.com/feed/update/urn:li:activity:7115868155998007296?updateEntityUrn=urn%3Ali%3Afs_updateV2%3A%28urn%3Ali%3Aactivity%3A7115868155998007296%2CMEMBER_SHARES%2CEMPTY%2CDEFAULT%2Cfalse%29&originTrackingId=oRXVfiURliJUdCi%2BBlpqXg%3D%3D'},
#    'text': {'textDirection': 'USER_LOCALE',
#     'attributes': [{'start': 0,
#       'length': 6,
#       'miniProfile': {'firstName': 'Lan',
#        'lastName': 'G.',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAYIxg8BxNB9SLTgtaZAbzzCHTpK4EyIq24',
#        'occupation': 'Machine Learning | Research Engineer',
#        'objectUrn': 'urn:li:member:101238287',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAAYIxg8BxNB9SLTgtaZAbzzCHTpK4EyIq24',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1676568011762?e=1745452800&v=beta&t=dzc74zsEfv_F20sJMtMbxzCl9q2htxAgGqL-3iDujyY',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 1400,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1676568011762?e=1745452800&v=beta&t=f19j9ycY8m3wt6tiosqKkNTi2H-O0CGUBJs80WC1wmA',
#            'expiresAt': 1745452800000,
#            'height': 350}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/D4E16AQHcL0EcRVVeJg/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'lan-gong',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1581190098755?e=1745452800&v=beta&t=tso5ihBpFHKWbD1K_xIzRFIMy_3IMtVm2pWxFdTnXwY',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1581190098726?e=1745452800&v=beta&t=_HXcXdcH9RKylK8op4cqXZQTnF6aPouomnjmtYErMQg',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1581190098795?e=1745452800&v=beta&t=fSSmDtuoQtbEY4scDst5ry1Gs0g5XCWHF__xi8b4T8o',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1581190098838?e=1745452800&v=beta&t=TdLnpU4Iwpv1sMIcunmZVoDuykRgvvjMMG7CfENhrb8',
#            'expiresAt': 1745452800000,
#            'height': 800}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4E03AQE-BYC1Qpv__A/profile-displayphoto-shrink_'}},
#        'trackingId': 'ahikusFOQzyIgwhB+ciAig=='},
#       'type': 'PROFILE_FULLNAME'}],
#     'text': 'Lan G. reposted this'},
#    'imageNavigationContext': {'trackingActionType': 'viewMember',
#     'accessibilityText': 'View Lan G.’s profile',
#     'actionTarget': 'https://www.linkedin.com/in/lan-gong?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAYIxg8BxNB9SLTgtaZAbzzCHTpK4EyIq24'}},
#   'content': {'com.linkedin.voyager.feed.render.ArticleComponent': {'urn': 'urn:li:article:6975879974068826895',
#     'headlineBackgroundColor': 'DEFAULT',
#     'swapTitleAndSubtitle': False,
#     'saveAction': {'entityUrn': 'urn:li:fs_saveAction:(SAVE,urn:li:article:6975879974068826895)',
#      'saved': False,
#      'dashEntityUrn': 'urn:li:fsd_saveState:(SAVE,urn:li:article:6975879974068826895)'},
#     'smallImage': {'accessibilityTextAttributes': [],
#      'attributes': [{'useCropping': True,
#        'sourceType': 'VECTOR',
#        'vectorImage': {'artifacts': [{'width': 800,
#           'fileIdentifyingUrlPathSegment': '800/articleshare-shrink_800/0/1731922420965?e=1740445200&v=beta&t=bLy43dVJjWcXADZ555ErfTCv0sFedwnoQGZ5XCLe2_M',
#           'expiresAt': 1740445200000,
#           'height': 420},
#          {'width': 1200,
#           'fileIdentifyingUrlPathSegment': '1280_800/articleshare-shrink_1280_800/0/1731922420965?e=1740445200&v=beta&t=TbD3aUmxC5fwN_yRL_Yk4Fb4a-r8Mn_x5f3lqGP1OcQ',
#           'expiresAt': 1740445200000,
#           'height': 630},
#          {'width': 160,
#           'fileIdentifyingUrlPathSegment': '160/articleshare-shrink_160/0/1731922420965?e=1740445200&v=beta&t=3LXVhAR-7nKxVV3XKg9wcIKjLHlvHasKFqscpRqESlg',
#           'expiresAt': 1740445200000,
#           'height': 84},
#          {'width': 480,
#           'fileIdentifyingUrlPathSegment': '480/articleshare-shrink_480/0/1731922420966?e=1740445200&v=beta&t=8bha-0l6j2mjWQMZH4T66KcAKT3aPkgN9sBfNTmiZZ4',
#           'expiresAt': 1740445200000,
#           'height': 252}],
#         'rootUrl': 'https://media.licdn.com/dms/image/sync/v2/D4E27AQESSpoADhsX9A/articleshare-shrink_'},
#        'displayAspectRatio': 0.5625}]},
#     'subtitle': {'textDirection': 'USER_LOCALE', 'text': 'run.house'},
#     'navigationContext': {'trackingActionType': 'viewLink',
#      'accessibilityText': 'Open article: Packaging Hell is Dragging ML by run.house',
#      'actionTarget': 'https://www.run.house/blog/orchestration-and-execution'},
#     'showSmallTitle': False,
#     'type': 'EXTERNAL_FULL',
#     'title': {'textDirection': 'FIRST_STRONG',
#      'text': 'Packaging Hell is Dragging ML'}}},
#   'commentary': {'numLines': 3,
#    'text': {'textDirection': 'FIRST_STRONG',
#     'attributes': [{'start': 307,
#       'length': 8,
#       'miniCompany': {'objectUrn': 'urn:li:company:25678724',
#        'entityUrn': 'urn:li:fs_miniCompany:25678724',
#        'name': 'Runhouse',
#        'showcase': False,
#        'active': True,
#        'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1673855404901/run_house_logo?e=1747872000&v=beta&t=bTxHiboGZQdn21C4iVgvlh4052VbfLmxGViEKpwoNAY',
#            'expiresAt': 1747872000000,
#            'height': 200},
#           {'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1673855404901/run_house_logo?e=1747872000&v=beta&t=tQibc9Cs9-JAZlcNyjgx081stxBViHvehECNFwMyudk',
#            'expiresAt': 1747872000000,
#            'height': 100},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1673855404901/run_house_logo?e=1747872000&v=beta&t=hyRqN0oIxJgWXgXmjH1U4EMxWRzwvQohOfsTTJv1qdQ',
#            'expiresAt': 1747872000000,
#            'height': 400}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C560BAQGEB_FYsoYVyw/company-logo_'}},
#        'universalName': 'run-house',
#        'dashCompanyUrn': 'urn:li:fsd_company:25678724',
#        'trackingId': 'lAi0/+MDSuqW57I4XhUL2A=='},
#       'type': 'COMPANY_NAME'},
#      {'start': 493,
#       'length': 14,
#       'miniProfile': {'firstName': 'Tullie',
#        'lastName': 'Murrell',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAABLBIOYBhhkxKW_NhwKD6NnpBe70ztxuKMA',
#        'occupation': 'CEO & Co-Founder @ Shaped (YC W22) | Ex-FAIR',
#        'objectUrn': 'urn:li:member:314646758',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAABLBIOYBhhkxKW_NhwKD6NnpBe70ztxuKMA',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1721166607640?e=1745452800&v=beta&t=FXkP4lu8P38y8ymgFab1kbBTrpqji5pSinuQl0cDu0E',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 1400,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1721166607640?e=1745452800&v=beta&t=C-Wj7UIu9IjkptWUz-dGiZte6_XPwY-e-RSqxuVuqr4',
#            'expiresAt': 1745452800000,
#            'height': 350}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/D4E16AQHPiMen5woPvQ/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'tullie',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1721174286221?e=1745452800&v=beta&t=vxtWt8UwwZQut7UnHy2kHs3UMBV5TpvXWEScH4CGcdY',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1721174286221?e=1745452800&v=beta&t=GIgGTY1_Pyi97aUQo1CxAEcAmyCvZjqCPnFgCsX_pwk',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1721174286221?e=1745452800&v=beta&t=XCLXOYEn_gVvh93k-VLyLiponmcA6qpaOHhpT69feZQ',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1721174286283?e=1745452800&v=beta&t=WDGXsvQnURu2gLDiomMA_1wAa-dJZYB90mJklMD6eT4',
#            'expiresAt': 1745452800000,
#            'height': 800}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/D5603AQHFI_Grbd88AQ/profile-displayphoto-shrink_'}},
#        'trackingId': '5qhXZkYfT1WRwATD0GvbUw=='},
#       'type': 'PROFILE_MENTION'},
#      {'start': 509,
#       'length': 14,
#       'miniProfile': {'firstName': 'Jeremiah',
#        'lastName': 'Lowin',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAAd6d0B3uL9zpCsq9eYWKi3HIvb8eN_r_Q',
#        'occupation': 'CEO at Prefect. Mostly harmless.',
#        'objectUrn': 'urn:li:member:1960413',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAAAd6d0B3uL9zpCsq9eYWKi3HIvb8eN_r_Q',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1693498465440?e=1745452800&v=beta&t=31sd2ngjxPaob0h4T9xC5GZczqSCNZ3n_bDNOTXBEMs',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 1400,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1693498465440?e=1745452800&v=beta&t=tAkcR_vUnlAKNA_K5sx6_qbT0gUAlk9OsRyblGss3mc',
#            'expiresAt': 1745452800000,
#            'height': 350}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/D4E16AQGNogJKzBuaGA/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'jlowin',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1571326979243?e=1745452800&v=beta&t=Eds-ZHyDozf89vjZUG-xRgfM0SnehLlwItFvBGVIKEE',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1571326979203?e=1745452800&v=beta&t=xAbftzDKM35G_6sOM2zcigaEKjkoBubXau3BLOBd1BQ',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1571326979281?e=1745452800&v=beta&t=LKtlCXPHymehh58UJDruC_Ebf3Hy0ohCS6VUGHOHZiw',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 473,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1571326979318?e=1745452800&v=beta&t=pTJBTUyvUZRoB7dlpAN93kpbOqKkjnv-M3GCU6HYRYw',
#            'expiresAt': 1745452800000,
#            'height': 473}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4E03AQFc2rrNjmqZ9Q/profile-displayphoto-shrink_'}},
#        'trackingId': 'X6/lngCVS4mDSsyTCPYuzg=='},
#       'type': 'PROFILE_MENTION'},
#      {'start': 525,
#       'length': 12,
#       'miniProfile': {'firstName': 'Flaviu',
#        'lastName': 'Vadan',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAABwawP4BujCMB2HzIRe-u9v_I476nYvh84E',
#        'occupation': 'Senior Software Engineer at Xaira Therapeutics',
#        'objectUrn': 'urn:li:member:471515390',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAABwawP4BujCMB2HzIRe-u9v_I476nYvh84E',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1517831175959?e=1745452800&v=beta&t=v4gMXyT_66nqhENSTdwLax5uO7gqUms6uWw3yVhal0U',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 1400,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1517831175847?e=1745452800&v=beta&t=Tm9QdVvqYDWx5FACBz3Ho6IoqF1dHt1YHAAzCVOfsdY',
#            'expiresAt': 1745452800000,
#            'height': 350}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5616AQGvsqJxEDKUIw/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'flaviuvadan',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1728840121140?e=1745452800&v=beta&t=oMbB6H7xU4FAFnnKD5mpjFhsHal12QP4cPhEyXuHtjY',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1728840121140?e=1745452800&v=beta&t=grLwZn8U4XRazmZJPt0BCXgbvG1YgOByz1N86aMeOOU',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1728840121140?e=1745452800&v=beta&t=0XspFV5PBIYiaOAxPa7KTGA1iuafO4mjHsqw-okkPr0',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1728840121153?e=1745452800&v=beta&t=oHhUvDAC_XNFCiniI9V9DmZ-kXwE5rABzdoowN-CVp8',
#            'expiresAt': 1745452800000,
#            'height': 800}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/D5603AQGz6WgVapziBQ/profile-displayphoto-shrink_'}},
#        'trackingId': 'Uni8xpxoQ1mFVSYXJLUPEQ=='},
#       'type': 'PROFILE_MENTION'},
#      {'start': 539,
#       'length': 15,
#       'miniProfile': {'firstName': 'Priyanka',
#        'lastName': 'Somrah',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAACykCUsBXq8rMDnAtnSikbTofWSgZvUpR1w',
#        'occupation': 'Principal at Work-Bench, leading seed investments in companies across cloud infrastructure, ML and developer tools',
#        'objectUrn': 'urn:li:member:748947787',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAACykCUsBXq8rMDnAtnSikbTofWSgZvUpR1w',
#        'publicIdentifier': 'priyanka-somrah',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1625610135037?e=1745452800&v=beta&t=9co0n6jBfA8FQGftUKrx2_mGTfrTooqFfWi5STAzPz4',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1625610135037?e=1745452800&v=beta&t=5g9SOtCpu0OCLR_tllC8HyDu3-SpXi-L6PRkUGCEzS8',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1625610135037?e=1745452800&v=beta&t=fY4D5i6nmaPyHBh0C_WL4uAdvN7R5oQFJD4lvYdYJQY',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1625610135037?e=1745452800&v=beta&t=qf85SyU8dtPdGrLzC72qdS7u5e_HAvnFZga3k3ePr-c',
#            'expiresAt': 1745452800000,
#            'height': 800}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4E03AQGUDE7T38LbEg/profile-displayphoto-shrink_'}},
#        'trackingId': 'Kp2AybkhS36uf2e5dXrocA=='},
#       'type': 'PROFILE_MENTION'},
#      {'start': 556,
#       'length': 13,
#       'miniProfile': {'firstName': 'Caroline',
#        'lastName': 'Chen',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAABVRmhUBiLvXEhQUVMo2pJl2D4qf83-YDGo',
#        'occupation': 'Software Engineer',
#        'objectUrn': 'urn:li:member:357669397',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAABVRmhUBiLvXEhQUVMo2pJl2D4qf83-YDGo',
#        'publicIdentifier': 'caroline-chen',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1526362495836?e=1745452800&v=beta&t=ywBb6vI96UuQRu41PMAhaCPIYQTJgaNa47a2ZcuNhX4',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1526362495883?e=1745452800&v=beta&t=-4zflmeWyXP_-0n-KJVh1obAuXfB0kFodZZ95N2bH94',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1526362495951?e=1745452800&v=beta&t=jSQXTvTpVn-GBgYnGERgOqqg2Ew0t2h-oqlbgofHMR0',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 450,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1526362495927?e=1745452800&v=beta&t=jSBzRF9GX0lR_ZafE_hOkfxqUxtFJ8EaaHr6TrkQmXw',
#            'expiresAt': 1745452800000,
#            'height': 450}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4E03AQGm13nZCWBTcw/profile-displayphoto-shrink_'}},
#        'trackingId': 'EkjiGjfiSwq8DZzMvVfJhQ=='},
#       'type': 'PROFILE_MENTION'},
#      {'start': 575,
#       'length': 7,
#       'miniProfile': {'firstName': 'Denis',
#        'lastName': 'K',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAACLl2wBSvFr7GJVhfYmeInY9oZJYU2pnB8',
#        'occupation': 'Staff Software Engineer',
#        'objectUrn': 'urn:li:member:9148268',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAACLl2wBSvFr7GJVhfYmeInY9oZJYU2pnB8',
#        'publicIdentifier': 'denis-k-1780923',
#        'trackingId': 'BCfQuEnRQCeHAfWEKxEhpg=='},
#       'type': 'PROFILE_MENTION'}],
#     'text': "We're finally in sight of fixing the hellish developer experience and research-to-production path in ML. It starts with software engineering fundamentals: Decoupling systems to be able to iterate, debug, and version them independently.\n\nThis was the original hypothesis that led me to leave Meta to work on Runhouse full time. Please share with your ML Engineer and Data Scientist friends who will pearl-clutch and share their strongly-worded opinions 👊👊👊\n\nhttps://lnkd.in/eJUTratG\n\nThanks to Tullie Murrell, Jeremiah Lowin, Flaviu Vadan, Priyanka Somrah, Caroline Chen, and Denis K for helpful conversations and feedback on this monstrosity."}},
#   'socialDetail': {'dashEntityUrn': 'urn:li:fsd_socialDetail:(urn:li:activity:7115580246564720640,urn:li:activity:7115580246564720640,urn:li:highlightedReply:-)',
#    'comments': {'paging': {'start': 0, 'count': 0, 'total': 0, 'links': []},
#     'elements': []},
#    'socialPermissions': {'dashEntityUrn': 'urn:li:fsd_socialPermissions:(urn:li:activity:7115580246564720640,urn:li:fsd_profile:ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk)',
#     'canPostComments': True,
#     'entityUrn': 'urn:li:fs_socialPermissions:(urn:li:activity:7115580246564720640,urn:li:fs_profile:(ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk,en_US))',
#     'messagePermission': 'PUBLIC',
#     'canShare': True,
#     'canReact': True},
#    'showPremiumAnalytics': False,
#    'hideFirstPrompt': True,
#    'liked': False,
#    'showShareButton': True,
#    'totalShares': 8,
#    'urn': 'urn:li:activity:7115580246564720640',
#    'threadId': 'activity:7115580246564720640',
#    'allowedCommentersScope': 'ALL',
#    'totalSocialActivityCounts': {'socialDetailEntityUrn': 'urn:li:fs_socialDetail:urn:li:activity:7115580246564720640',
#     'urn': 'urn:li:activity:7115580246564720640',
#     'numComments': 0,
#     'dashEntityUrn': 'urn:li:fsd_socialActivityCounts:urn:li:activity:7115580246564720640',
#     'reactionTypeCounts': [{'count': 60, 'reactionType': 'LIKE'},
#      {'count': 5, 'reactionType': 'PRAISE'},
#      {'count': 4, 'reactionType': 'EMPATHY'},
#      {'count': 2, 'reactionType': 'INTEREST'}],
#     'entityUrn': 'urn:li:fs_socialActivityCounts:urn:li:activity:7115580246564720640',
#     'numShares': 8,
#     'numLikes': 71,
#     'liked': False},
#    'entityUrn': 'urn:li:fs_socialDetail:urn:li:activity:7115580246564720640',
#    'commentingDisabled': False,
#    'likes': {'paging': {'start': 0, 'count': 0, 'total': 71, 'links': []},
#     'elements': []}}}]

# %%
p2_posts = api.get_profile_posts(urn_id=people[2]['urn_id'])
len(p2_posts)
# Out:
# 8

# %%
with open("p2_posts.json", "w", encoding="utf-8") as f:
    json.dump(p2_posts, f, indent=4, ensure_ascii=False)

p2_posts
# Out:
# [{'actor': {'urn': 'urn:li:company:29330198',
#    'image': {'accessibilityTextAttributes': [],
#     'attributes': [{'miniCompany': {'objectUrn': 'urn:li:company:29330198',
#        'entityUrn': 'urn:li:fs_miniCompany:29330198',
#        'name': 'Apziva',
#        'showcase': False,
#        'active': True,
#        'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630691803756/apziva_logo?e=1747872000&v=beta&t=40lSzVBqxadDd5ZX7t_YCnkqUcBj7cRlEyJjlcKQIHY',
#            'expiresAt': 1747872000000,
#            'height': 200},
#           {'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630691803756/apziva_logo?e=1747872000&v=beta&t=b5085k35-OnWOuloj3dA0RCa8e9NC7gqO-sVIh6l5Y8',
#            'expiresAt': 1747872000000,
#            'height': 100},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630691803756/apziva_logo?e=1747872000&v=beta&t=9aI2uLddvr3BqPPuIogYBwuyt8M7E3draSKyB-UYW4g',
#            'expiresAt': 1747872000000,
#            'height': 400}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4E0BAQHuarpHGtpKxw/company-logo_'}},
#        'universalName': 'apziva',
#        'dashCompanyUrn': 'urn:li:fsd_company:29330198',
#        'trackingId': 'LM8gU4tDSju3jtX/oAno2w=='},
#       'sourceType': 'COMPANY_LOGO'}]},
#    'name': {'textDirection': 'FIRST_STRONG',
#     'attributes': [{'start': 0,
#       'length': 6,
#       'miniCompany': {'objectUrn': 'urn:li:company:29330198',
#        'entityUrn': 'urn:li:fs_miniCompany:29330198',
#        'name': 'Apziva',
#        'showcase': False,
#        'active': True,
#        'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630691803756/apziva_logo?e=1747872000&v=beta&t=40lSzVBqxadDd5ZX7t_YCnkqUcBj7cRlEyJjlcKQIHY',
#            'expiresAt': 1747872000000,
#            'height': 200},
#           {'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630691803756/apziva_logo?e=1747872000&v=beta&t=b5085k35-OnWOuloj3dA0RCa8e9NC7gqO-sVIh6l5Y8',
#            'expiresAt': 1747872000000,
#            'height': 100},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630691803756/apziva_logo?e=1747872000&v=beta&t=9aI2uLddvr3BqPPuIogYBwuyt8M7E3draSKyB-UYW4g',
#            'expiresAt': 1747872000000,
#            'height': 400}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4E0BAQHuarpHGtpKxw/company-logo_'}},
#        'universalName': 'apziva',
#        'dashCompanyUrn': 'urn:li:fsd_company:29330198',
#        'trackingId': 'LM8gU4tDSju3jtX/oAno2w=='},
#       'type': 'COMPANY_NAME'}],
#     'text': 'Apziva',
#     'accessibilityText': 'Apziva'},
#    'subDescription': {'textDirection': 'USER_LOCALE',
#     'attributes': [{'start': 15,
#       'length': 1,
#       'artDecoIcon': 'IC_GLOBE_16DP',
#       'type': 'ART_DECO_ICON'}],
#     'text': '2mo • Edited •   ',
#     'accessibilityText': '3 months ago'},
#    'navigationContext': {'trackingActionType': 'viewAttributedCompany',
#     'accessibilityText': 'View company: Apziva',
#     'actionTarget': 'https://www.linkedin.com/company/apziva/posts'},
#    'description': {'textDirection': 'USER_LOCALE',
#     'accessibilityText': '46,687 followers',
#     'text': '46,687 followers'},
#    'followAction': {'followTrackingActionType': 'followCompany',
#     'companyFollowingTrackingContext': 'MOBILE_NON_SSU',
#     'followingInfo': {'followingType': 'DEFAULT',
#      'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:29330198',
#      'followerCount': 46687,
#      'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:29330198',
#      'following': False,
#      'trackingUrn': 'urn:li:company:29330198'},
#     'unfollowTrackingActionType': 'unfollowCompany',
#     'type': 'FOLLOW_TOGGLE',
#     'trackingActionType': 'followCompany'}},
#   'dashEntityUrn': 'urn:li:fsd_update:(urn:li:activity:7274136332082241536,MEMBER_SHARES,EMPTY,DEFAULT,false)',
#   'updateMetadata': {'urn': 'urn:li:activity:7274136332082241536',
#    'actionsPosition': 'HEADER_COMPONENT',
#    'updateActions': {'actions': [{'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_BOOKMARK_OUTLINE_MEDIUM'}]},
#       'actionType': 'SAVE',
#       'saveAction': {'entityUrn': 'urn:li:fs_saveAction:(SAVE,urn:li:activity:7266814202311311360)',
#        'saved': False,
#        'dashEntityUrn': 'urn:li:fsd_saveState:(SAVE,urn:li:activity:7266814202311311360)'},
#       'text': 'Save'},
#      {'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_LINK_MEDIUM'}]},
#       'actionType': 'SHARE_VIA',
#       'text': 'Copy link to post',
#       'url': 'https://www.linkedin.com/posts/apziva_why-join-an-apziva-webinar-ugcPost-7266814200960753664-pOew?utm_source=share&utm_medium=member_desktop&rcm=ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk'},
#      {'actionType': 'REPORT',
#       'targetUrn': 'urn:li:ugcPost:7266814200960753664',
#       'contentSource': 'UGC_POST',
#       'authorUrn': 'urn:li:company:29330198',
#       'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_REPORT_MEDIUM'}]},
#       'secondaryAction': {'icon': {'accessibilityTextAttributes': [],
#         'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#           'systemImage': 'SYS_ICN_VISIBILITY_OFF_MEDIUM'}]},
#        'actionType': 'HIDE_UPDATE',
#        'targetUrn': 'urn:li:activity:7274136332082241536',
#        'text': 'Hide this post',
#        'confirmationAction': {'title': {'textDirection': 'USER_LOCALE',
#          'text': 'Post removed'},
#         'description': {'textDirection': 'USER_LOCALE',
#          'text': "You'll no longer see this post in your feed."},
#         'undoable': True}},
#       'text': 'Report post',
#       'confirmationAction': {'title': {'textDirection': 'USER_LOCALE',
#         'text': 'Thank you for your report'},
#        'description': {'textDirection': 'USER_LOCALE',
#         'text': 'We appreciate you letting us know'},
#        'undoable': False}}],
#     'entityUrn': 'urn:li:fs_updateV2Actions:(urn:li:activity:7274136332082241536,MEMBER_SHARES,EMPTY,-,-)',
#     'dashEntityUrn': 'urn:li:fsd_updateActions:(urn:li:activity:7274136332082241536,MEMBER_SHARES,EMPTY,urn:li:reason:-,urn:li:adCreative:-)'},
#    'actionTriggerEnabled': False,
#    'detailPageType': 'FEED_DETAIL',
#    'shareAudience': 'PUBLIC',
#    'shareUrn': 'urn:li:ugcPost:7266814200960753664',
#    'excludedFromSeen': False,
#    'rootShare': True,
#    'trackingData': {'requestId': 'f9bba9da-4161-4183-9481-b22fbf1ad556',
#     'trackingId': '1frcS1anZTOz2eq4bEMzuQ=='}},
#   'socialContent': {'updateSaveActionToolTipLegoTrackingToken': '...',
#    'shareUrl': 'https://www.linkedin.com/posts/apziva_why-join-an-apziva-webinar-ugcPost-7266814200960753664-pOew?utm_source=combined_share_message&utm_medium=member_desktop&rcm=ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk'},
#   'entityUrn': 'urn:li:fs_updateV2:(urn:li:activity:7274136332082241536,MEMBER_SHARES,EMPTY,DEFAULT,false)',
#   'header': {'image': {'accessibilityTextAttributes': [],
#     'accessibilityText': 'Mireille P.’s profile photo',
#     'attributes': [{'sourceType': 'PROFILE_PICTURE',
#       'miniProfile': {'firstName': 'Mireille P.',
#        'lastName': 'Feudjio T. (Ph.D)',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#        'occupation': 'Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life',
#        'objectUrn': 'urn:li:member:161574362',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 756,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1594850407815?e=1745452800&v=beta&t=E54mej56CN7VO4Tf6cqOVfdyk4vWgCeN7R8ymiYhnBU',
#            'expiresAt': 1745452800000,
#            'height': 189},
#           {'width': 756,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1594850407815?e=1745452800&v=beta&t=6f44rst3vHD8lEf5UiXeXJQiTA16XzskxQlJZTsoz9Y',
#            'expiresAt': 1745452800000,
#            'height': 189}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5616AQEwori0Cjg1uw/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'feudjiotmp',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1642571081110?e=1745452800&v=beta&t=Ma00Qth43CNWpaBnrPXxmg03LTbcVxJJloLwURQ7LSQ',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1642571081110?e=1745452800&v=beta&t=kp8k0k29gYnqk1hNDjsRl1qBGgzjZAw-hwSgWgkRbzY',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1642571081110?e=1745452800&v=beta&t=hhSYva3TOt5cLclna7sqUMp6adm0-aR8Fp4f1Fj7R9o',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 612,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1642571081110?e=1745452800&v=beta&t=_OAKfbg3YV_YrlSKLIFOXs_2-QpGVMplnZrkcrnb_MU',
#            'expiresAt': 1745452800000,
#            'height': 612}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5603AQHnaTb2Ddmq0A/profile-displayphoto-shrink_'}},
#        'trackingId': 'KogAEh0bTTSvpf0u3GduRw=='}}]},
#    'navigationContext': {'trackingActionType': 'viewUpdateDetail',
#     'accessibilityText': 'View full post',
#     'actionTarget': 'https://www.linkedin.com/feed/update/urn:li:activity:7274136332082241536?updateEntityUrn=urn%3Ali%3Afs_updateV2%3A%28urn%3Ali%3Aactivity%3A7274136332082241536%2CMEMBER_SHARES%2CEMPTY%2CDEFAULT%2Cfalse%29&originTrackingId=1frcS1anZTOz2eq4bEMzuQ%3D%3D'},
#    'text': {'textDirection': 'USER_LOCALE',
#     'attributes': [{'start': 0,
#       'length': 29,
#       'miniProfile': {'firstName': 'Mireille P.',
#        'lastName': 'Feudjio T. (Ph.D)',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#        'occupation': 'Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life',
#        'objectUrn': 'urn:li:member:161574362',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 756,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1594850407815?e=1745452800&v=beta&t=E54mej56CN7VO4Tf6cqOVfdyk4vWgCeN7R8ymiYhnBU',
#            'expiresAt': 1745452800000,
#            'height': 189},
#           {'width': 756,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1594850407815?e=1745452800&v=beta&t=6f44rst3vHD8lEf5UiXeXJQiTA16XzskxQlJZTsoz9Y',
#            'expiresAt': 1745452800000,
#            'height': 189}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5616AQEwori0Cjg1uw/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'feudjiotmp',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1642571081110?e=1745452800&v=beta&t=Ma00Qth43CNWpaBnrPXxmg03LTbcVxJJloLwURQ7LSQ',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1642571081110?e=1745452800&v=beta&t=kp8k0k29gYnqk1hNDjsRl1qBGgzjZAw-hwSgWgkRbzY',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1642571081110?e=1745452800&v=beta&t=hhSYva3TOt5cLclna7sqUMp6adm0-aR8Fp4f1Fj7R9o',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 612,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1642571081110?e=1745452800&v=beta&t=_OAKfbg3YV_YrlSKLIFOXs_2-QpGVMplnZrkcrnb_MU',
#            'expiresAt': 1745452800000,
#            'height': 612}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5603AQHnaTb2Ddmq0A/profile-displayphoto-shrink_'}},
#        'trackingId': 'KogAEh0bTTSvpf0u3GduRw=='},
#       'type': 'PROFILE_FULLNAME'}],
#     'text': 'Mireille P. Feudjio T. (Ph.D) reposted this'},
#    'imageNavigationContext': {'trackingActionType': 'viewMember',
#     'accessibilityText': 'View Mireille P. Feudjio T. (Ph.D)’s profile',
#     'actionTarget': 'https://www.linkedin.com/in/feudjiotmp?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo'}},
#   'content': {'com.linkedin.voyager.feed.render.DocumentComponent': {'showDownloadCTA': False,
#     'document': {'transcribedDocumentUrl': 'https://media.licdn.com/dms/document/media/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-url-metadata-scrapper-pdf/feedshare-document-url-metadata-scrapper-pdf/0/1732543413684?e=1740448800&v=beta&t=hTKM9Cc2dccu8kpv3c8IEuotSPga4BSBACxsTZ-XzRQ',
#      'urn': 'urn:li:digitalmediaAsset:D4D1FAQHcmVR1AuI7ew',
#      'manifestUrl': 'https://media.licdn.com/dms/document/pl/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-master-manifest/feedshare-document-master-manifest/0/1732543414728?e=1740448800&v=beta&t=fYn31lnEvThMTw22UwTxorzywNKyTJMKcXZTKNs0NT4',
#      'scanRequiredForDownload': True,
#      'totalPageCount': 4,
#      'manifestUrlExpiresAt': 1740448800000,
#      'title': 'Why Join an Apziva Webinar',
#      'coverPages': {'transcripts': [],
#       'pagesPerResolution': [{'width': 483,
#         'height': 483,
#         'imageUrls': ['https://media.licdn.com/dms/image/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-cover-images_480/feedshare-document-cover-images_480/0/1732543413691?e=1740448800&v=beta&t=v-dcMGj--DQuCPBg3mWGj9oqgDQGWvqSnjOradt8mgY',
#          'https://media.licdn.com/dms/image/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-cover-images_480/feedshare-document-cover-images_480/1/1732543413691?e=1740448800&v=beta&t=9-4UFBWJbn_C8x9dtTjr6nSGBFeQrix4piZ8TO1sIvc',
#          'https://media.licdn.com/dms/image/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-cover-images_480/feedshare-document-cover-images_480/2/1732543413691?e=1740448800&v=beta&t=uc2OSAONH82ci4jImYmcgTngKQEaaQcIzWQuH7TIWAs']},
#        {'width': 810,
#         'height': 810,
#         'imageUrls': ['https://media.licdn.com/dms/image/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-cover-images_800/feedshare-document-cover-images_800/0/1732543413895?e=1740448800&v=beta&t=yCpSIr7duDqAuWQSE6YIHFiALPyjJgWfb638-E9TYps',
#          'https://media.licdn.com/dms/image/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-cover-images_800/feedshare-document-cover-images_800/1/1732543413895?e=1740448800&v=beta&t=RFVTZKA7hYA1hTIVgi32LE27VyNi0dPp7JBuTMvQWZc',
#          'https://media.licdn.com/dms/image/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-cover-images_800/feedshare-document-cover-images_800/2/1732543413895?e=1740448800&v=beta&t=2B6fwDPH8GsUSYSbNN6ULWr5_Kt-wChQkbpGgiZyBEM']},
#        {'width': 1282,
#         'height': 1282,
#         'imageUrls': ['https://media.licdn.com/dms/image/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-cover-images_1280/feedshare-document-cover-images_1280/0/1732543414144?e=1740448800&v=beta&t=sdCiYZta6YxZWXeT2ooUIpRNY2h3M33uBS3tW8cT-Bw',
#          'https://media.licdn.com/dms/image/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-cover-images_1280/feedshare-document-cover-images_1280/1/1732543414144?e=1740448800&v=beta&t=DQQ9QzY4OJZvlYUagFKh-K0y2IF0SQRH3Q1n1YfcwzQ',
#          'https://media.licdn.com/dms/image/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-cover-images_1280/feedshare-document-cover-images_1280/2/1732543414144?e=1740448800&v=beta&t=DK4H6P5Q3UvldlJEQPKG-HtA_LRtupyZ6XsOV3ojeQQ']},
#        {'width': 1923,
#         'height': 1923,
#         'imageUrls': ['https://media.licdn.com/dms/image/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-cover-images_1920/feedshare-document-cover-images_1920/0/1732543414734?e=1740448800&v=beta&t=0zm_A79WaumV80rKvdID9NF2H7DdhCX38VdL5wbsONg',
#          'https://media.licdn.com/dms/image/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-cover-images_1920/feedshare-document-cover-images_1920/1/1732543414734?e=1740448800&v=beta&t=z2TUP3vsayiADRuEZl05WHKXMEHFRi2mNLQsPQVzwjo',
#          'https://media.licdn.com/dms/image/v2/D4D1FAQHcmVR1AuI7ew/feedshare-document-cover-images_1920/feedshare-document-cover-images_1920/2/1732543414734?e=1740448800&v=beta&t=2AWADd-9q_B27jY9J3uNsAkyJ3M2X0s-_NewIsFH68A']}]},
#      'transcribedDocumentUrlExpiresAt': 1740448800000}}},
#   'commentary': {'numLines': 3,
#    'text': {'textDirection': 'FIRST_STRONG',
#     'attributes': [{'start': 140,
#       'length': 15,
#       'miniProfile': {'firstName': 'Semih',
#        'lastName': 'Yagcioglu',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAKWgswB_2UGGzlrAcIZM4jJQ8vBht5GIsA',
#        'occupation': "Director of AI @ Apziva - We're hiring!",
#        'objectUrn': 'urn:li:member:43418316',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAAKWgswB_2UGGzlrAcIZM4jJQ8vBht5GIsA',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1697004360443?e=1745452800&v=beta&t=Og5sF4OxQzGO7jej6gBP8kymNoIEOsBLjwsaAR3Ox0c',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 1400,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1697004360444?e=1745452800&v=beta&t=Ofwu6iSi3sIcOeJIxnGYMcsnqEQBU32853Y22WqQR98',
#            'expiresAt': 1745452800000,
#            'height': 350}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/D4D16AQFf6bcXLRCT2g/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'semih',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1527788758697?e=1745452800&v=beta&t=8R46HS64WdveIWDDAEx5rO8YRCo0GvahF7vBWPQBXPs',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1527788758708?e=1745452800&v=beta&t=ShxQmdGMEjkJftpkzKraLcDMA9sg3CwAmLD6ESkitjQ',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1527788758986?e=1745452800&v=beta&t=b4GQcU5l1aFyloJvpLdOq0yfvXNZmYWAx8g5r36FDvA',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1527788758957?e=1745452800&v=beta&t=1eX64yLcuQyK9pQQXOhqBoV0vaMVMWIYecxh-KCb29s',
#            'expiresAt': 1745452800000,
#            'height': 800}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4E03AQHbuI4Eu36A_A/profile-displayphoto-shrink_'}},
#        'trackingId': 'Cjq6dj8jS3KNSNNsZKFmTw=='},
#       'type': 'PROFILE_MENTION'}],
#     'text': 'Looking to level up your career in data science? \n👉 Swipe right to find out why Apziva webinars are essential for career transitioners.\n\nAs Semih Yagcioglu says:\n"Job searching is hard. Every day you question yourself. This is why Apziva webinars exist—to help career transitioners break into machine learning and data science."\n\n🌟 #AIResidency #DataScienceSuccess #CareerGrowth'}},
#   'socialDetail': {'reactionElements': [],
#    'dashEntityUrn': 'urn:li:fsd_socialDetail:(urn:li:ugcPost:7266814200960753664,urn:li:activity:7274136332082241536,urn:li:highlightedReply:-)',
#    'comments': {'paging': {'start': 0, 'count': 0, 'total': 1, 'links': []},
#     'elements': []},
#    'socialPermissions': {'dashEntityUrn': 'urn:li:fsd_socialPermissions:(urn:li:ugcPost:7266814200960753664,urn:li:fsd_profile:ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk)',
#     'canPostComments': True,
#     'entityUrn': 'urn:li:fs_socialPermissions:(urn:li:ugcPost:7266814200960753664,urn:li:fs_profile:(ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk,en_US))',
#     'messagePermission': 'PUBLIC',
#     'canShare': True,
#     'canReact': True},
#    'showPremiumAnalytics': False,
#    'hideFirstPrompt': True,
#    'liked': False,
#    'showShareButton': True,
#    'totalShares': 5,
#    'urn': 'urn:li:ugcPost:7266814200960753664',
#    'threadId': 'ugcPost:7266814200960753664',
#    'allowedCommentersScope': 'ALL',
#    'totalSocialActivityCounts': {'socialDetailEntityUrn': 'urn:li:fs_socialDetail:urn:li:ugcPost:7266814200960753664',
#     'urn': 'urn:li:ugcPost:7266814200960753664',
#     'numComments': 1,
#     'dashEntityUrn': 'urn:li:fsd_socialActivityCounts:urn:li:ugcPost:7266814200960753664',
#     'reactionTypeCounts': [{'count': 15, 'reactionType': 'LIKE'},
#      {'count': 3, 'reactionType': 'PRAISE'}],
#     'entityUrn': 'urn:li:fs_socialActivityCounts:urn:li:ugcPost:7266814200960753664',
#     'numShares': 5,
#     'numLikes': 18,
#     'liked': False},
#    'entityUrn': 'urn:li:fs_socialDetail:urn:li:ugcPost:7266814200960753664',
#    'commentingDisabled': False,
#    'likes': {'paging': {'count': 0, 'start': 0, 'total': 18, 'links': []},
#     'elements': []}}},
#  {'actor': {'urn': 'urn:li:member:161574362',
#    'image': {'accessibilityTextAttributes': [],
#     'attributes': [{'sourceType': 'PROFILE_PICTURE',
#       'miniProfile': {'firstName': 'Mireille P.',
#        'lastName': 'Feudjio T. (Ph.D)',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#        'occupation': 'Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life',
#        'objectUrn': 'urn:li:member:161574362',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 756,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1594850407815?e=1745452800&v=beta&t=E54mej56CN7VO4Tf6cqOVfdyk4vWgCeN7R8ymiYhnBU',
#            'expiresAt': 1745452800000,
#            'height': 189},
#           {'width': 756,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1594850407815?e=1745452800&v=beta&t=6f44rst3vHD8lEf5UiXeXJQiTA16XzskxQlJZTsoz9Y',
#            'expiresAt': 1745452800000,
#            'height': 189}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5616AQEwori0Cjg1uw/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'feudjiotmp',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1642571081110?e=1745452800&v=beta&t=Ma00Qth43CNWpaBnrPXxmg03LTbcVxJJloLwURQ7LSQ',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1642571081110?e=1745452800&v=beta&t=kp8k0k29gYnqk1hNDjsRl1qBGgzjZAw-hwSgWgkRbzY',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1642571081110?e=1745452800&v=beta&t=hhSYva3TOt5cLclna7sqUMp6adm0-aR8Fp4f1Fj7R9o',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 612,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1642571081110?e=1745452800&v=beta&t=_OAKfbg3YV_YrlSKLIFOXs_2-QpGVMplnZrkcrnb_MU',
#            'expiresAt': 1745452800000,
#            'height': 612}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5603AQHnaTb2Ddmq0A/profile-displayphoto-shrink_'}},
#        'trackingId': 'KogAEh0bTTSvpf0u3GduRw=='}}]},
#    'supplementaryActorInfo': {'textDirection': 'USER_LOCALE',
#     'accessibilityText': ' • 2nd',
#     'text': ' • 2nd'},
#    'name': {'textDirection': 'FIRST_STRONG',
#     'attributes': [{'start': 0,
#       'length': 29,
#       'miniProfile': {'firstName': 'Mireille P.',
#        'lastName': 'Feudjio T. (Ph.D)',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#        'occupation': 'Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life',
#        'objectUrn': 'urn:li:member:161574362',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 756,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1594850407815?e=1745452800&v=beta&t=E54mej56CN7VO4Tf6cqOVfdyk4vWgCeN7R8ymiYhnBU',
#            'expiresAt': 1745452800000,
#            'height': 189},
#           {'width': 756,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1594850407815?e=1745452800&v=beta&t=6f44rst3vHD8lEf5UiXeXJQiTA16XzskxQlJZTsoz9Y',
#            'expiresAt': 1745452800000,
#            'height': 189}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5616AQEwori0Cjg1uw/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'feudjiotmp',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1642571081110?e=1745452800&v=beta&t=Ma00Qth43CNWpaBnrPXxmg03LTbcVxJJloLwURQ7LSQ',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1642571081110?e=1745452800&v=beta&t=kp8k0k29gYnqk1hNDjsRl1qBGgzjZAw-hwSgWgkRbzY',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1642571081110?e=1745452800&v=beta&t=hhSYva3TOt5cLclna7sqUMp6adm0-aR8Fp4f1Fj7R9o',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 612,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1642571081110?e=1745452800&v=beta&t=_OAKfbg3YV_YrlSKLIFOXs_2-QpGVMplnZrkcrnb_MU',
#            'expiresAt': 1745452800000,
#            'height': 612}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5603AQHnaTb2Ddmq0A/profile-displayphoto-shrink_'}},
#        'trackingId': 'KogAEh0bTTSvpf0u3GduRw=='},
#       'type': 'PROFILE_FULLNAME'}],
#     'text': 'Mireille P. Feudjio T. (Ph.D)',
#     'accessibilityText': 'Mireille P. Feudjio T. (Ph.D)'},
#    'subDescription': {'textDirection': 'USER_LOCALE',
#     'attributes': [{'start': 6,
#       'length': 1,
#       'artDecoIcon': 'IC_GLOBE_16DP',
#       'type': 'ART_DECO_ICON'}],
#     'text': '1yr •   ',
#     'accessibilityText': '2 years ago'},
#    'navigationContext': {'trackingActionType': 'viewAttributedMember',
#     'accessibilityText': 'View Mireille P. Feudjio T. (Ph.D)’s profile',
#     'actionTarget': 'https://www.linkedin.com/in/feudjiotmp?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo'},
#    'description': {'textDirection': 'USER_LOCALE',
#     'accessibilityText': 'Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life',
#     'text': 'Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life'},
#    'followAction': {'followTrackingActionType': 'followMember',
#     'followingInfo': {'followingType': 'DEFAULT',
#      'entityUrn': 'urn:li:fs_followingInfo:urn:li:member:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#      'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_profile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#      'following': False,
#      'trackingUrn': 'urn:li:member:161574362'},
#     'unfollowTrackingActionType': 'unfollowMember',
#     'type': 'FOLLOW_TOGGLE',
#     'trackingActionType': 'followMember'}},
#   'dashEntityUrn': 'urn:li:fsd_update:(urn:li:activity:7041572736686518272,MEMBER_SHARES,EMPTY,DEFAULT,false)',
#   'updateMetadata': {'urn': 'urn:li:activity:7041572736686518272',
#    'actionsPosition': 'ACTOR_COMPONENT',
#    'updateActions': {'actions': [{'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_BOOKMARK_OUTLINE_MEDIUM'}]},
#       'actionType': 'SAVE',
#       'saveAction': {'entityUrn': 'urn:li:fs_saveAction:(SAVE,urn:li:activity:7041572736686518272)',
#        'saved': False,
#        'dashEntityUrn': 'urn:li:fsd_saveState:(SAVE,urn:li:activity:7041572736686518272)'},
#       'text': 'Save'},
#      {'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_LINK_MEDIUM'}]},
#       'actionType': 'SHARE_VIA',
#       'text': 'Copy link to post',
#       'url': 'https://www.linkedin.com/posts/feudjiotmp_going-places-with-spatial-analysis-activity-7041572736686518272-X7Y0?utm_source=share&utm_medium=member_desktop&rcm=ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk'},
#      {'actionType': 'REPORT',
#       'targetUrn': 'urn:li:ugcPost:7041572736007069696',
#       'contentSource': 'UGC_POST',
#       'authorProfileId': 'ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#       'authorUrn': 'urn:li:member:161574362',
#       'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_REPORT_MEDIUM'}]},
#       'secondaryAction': {'icon': {'accessibilityTextAttributes': [],
#         'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#           'systemImage': 'SYS_ICN_VISIBILITY_OFF_MEDIUM'}]},
#        'actionType': 'HIDE_UPDATE',
#        'targetUrn': 'urn:li:activity:7041572736686518272',
#        'text': 'Hide this post',
#        'confirmationAction': {'title': {'textDirection': 'USER_LOCALE',
#          'text': 'Post removed'},
#         'description': {'textDirection': 'USER_LOCALE',
#          'text': "You'll no longer see this post in your feed."},
#         'undoable': True}},
#       'text': 'Report post',
#       'confirmationAction': {'title': {'textDirection': 'USER_LOCALE',
#         'text': 'Thank you for your report'},
#        'description': {'textDirection': 'USER_LOCALE',
#         'text': 'We appreciate you letting us know'},
#        'undoable': False}}],
#     'entityUrn': 'urn:li:fs_updateV2Actions:(urn:li:activity:7041572736686518272,MEMBER_SHARES,EMPTY,-,-)',
#     'dashEntityUrn': 'urn:li:fsd_updateActions:(urn:li:activity:7041572736686518272,MEMBER_SHARES,EMPTY,urn:li:reason:-,urn:li:adCreative:-)'},
#    'actionTriggerEnabled': False,
#    'detailPageType': 'FEED_DETAIL',
#    'shareAudience': 'PUBLIC',
#    'shareUrn': 'urn:li:ugcPost:7041572736007069696',
#    'excludedFromSeen': False,
#    'rootShare': True,
#    'trackingData': {'requestId': 'f9bba9da-4161-4183-9481-b22fbf1ad556',
#     'trackingId': 'UIGZXubX9Q44lpCt6wZKfA=='}},
#   'socialContent': {'updateSaveActionToolTipLegoTrackingToken': '...',
#    'shareUrl': 'https://www.linkedin.com/posts/feudjiotmp_going-places-with-spatial-analysis-activity-7041572736686518272-X7Y0?utm_source=combined_share_message&utm_medium=member_desktop&rcm=ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk'},
#   'entityUrn': 'urn:li:fs_updateV2:(urn:li:activity:7041572736686518272,MEMBER_SHARES,EMPTY,DEFAULT,false)',
#   'content': {'com.linkedin.voyager.feed.render.DocumentComponent': {'showDownloadCTA': False,
#     'document': {'transcribedDocumentUrl': 'https://media.licdn.com/dms/document/media/v2/C4E1FAQGnYGAjIDGqvw/feedshare-document-url-metadata-scrapper-pdf/feedshare-document-url-metadata-scrapper-pdf/0/1678841697857?e=1740448800&v=beta&t=zB5Sx63pRJ3wpBPk1lseaqEOrWyJrHa6Xx7-p8gcrPY',
#      'urn': 'urn:li:digitalmediaAsset:C4E1FAQGnYGAjIDGqvw',
#      'manifestUrl': 'https://media.licdn.com/dms/document/pl/v2/C4E1FAQGnYGAjIDGqvw/feedshare-document-master-manifest/feedshare-document-master-manifest/0/1678841699114?e=1740448800&v=beta&t=mI1T-pCJ4ABwu0QwtFqHjzTHWRcbxkcYcDWJUDHSluk',
#      'scanRequiredForDownload': True,
#      'totalPageCount': 1,
#      'manifestUrlExpiresAt': 1740448800000,
#      'title': 'Going Places with Spatial Analysis',
#      'coverPages': {'transcripts': [],
#       'pagesPerResolution': [{'width': 491,
#         'height': 347,
#         'imageUrls': ['https://media.licdn.com/dms/image/v2/C4E1FAQGnYGAjIDGqvw/feedshare-document-cover-images_480/feedshare-document-cover-images_480/0/1678841698654?e=1740448800&v=beta&t=3orFSuKZzI-wGw-F4J3bASw6248dTBxXIUTcmm1LpQI']},
#        {'width': 806,
#         'height': 570,
#         'imageUrls': ['https://media.licdn.com/dms/image/v2/C4E1FAQGnYGAjIDGqvw/feedshare-document-cover-images_800/feedshare-document-cover-images_800/0/1678841698587?e=1740448800&v=beta&t=zAcArrzgjhoFTH3F151SSIWK_x-X-Vlqe33MnILuhTo']},
#        {'width': 1286,
#         'height': 909,
#         'imageUrls': ['https://media.licdn.com/dms/image/v2/C4E1FAQGnYGAjIDGqvw/feedshare-document-cover-images_1280/feedshare-document-cover-images_1280/0/1678841699111?e=1740448800&v=beta&t=e3y1tnAh2IVIEVryNROEdTtFKAeTlgFapgxkcvEx0Zc']},
#        {'width': 1929,
#         'height': 1363,
#         'imageUrls': ['https://media.licdn.com/dms/image/v2/C4E1FAQGnYGAjIDGqvw/feedshare-document-cover-images_1920/feedshare-document-cover-images_1920/0/1678841698700?e=1740448800&v=beta&t=DK7u2Ox44QYg4fccF4wQYUc-uBWXSGqHv79hzzyKtmM']}]},
#      'transcribedDocumentUrlExpiresAt': 1740448800000}}},
#   'commentary': {'numLines': 3,
#    'text': {'textDirection': 'FIRST_STRONG',
#     'text': 'It was an amazing experience to embark on a journey with "Going Places with Spatial Analysis", and I would like to extend my heartfelt gratitude to all the instructors involved. #spatialanalysis, #Argis, #datascience, #Density_analysis, #suitabilityanalysis, #classificationmap, #gravitymodel, #overlayanalysis, #spatialmodeling.'}},
#   'socialDetail': {'reactionElements': [],
#    'dashEntityUrn': 'urn:li:fsd_socialDetail:(urn:li:ugcPost:7041572736007069696,urn:li:ugcPost:7041572736007069696,urn:li:highlightedReply:-)',
#    'comments': {'paging': {'start': 0, 'count': 0, 'total': 3, 'links': []},
#     'elements': []},
#    'socialPermissions': {'dashEntityUrn': 'urn:li:fsd_socialPermissions:(urn:li:ugcPost:7041572736007069696,urn:li:fsd_profile:ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk)',
#     'canPostComments': True,
#     'entityUrn': 'urn:li:fs_socialPermissions:(urn:li:ugcPost:7041572736007069696,urn:li:fs_profile:(ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk,en_US))',
#     'messagePermission': 'PUBLIC',
#     'canShare': True,
#     'canReact': True},
#    'showPremiumAnalytics': False,
#    'hideFirstPrompt': True,
#    'liked': False,
#    'showShareButton': True,
#    'totalShares': 0,
#    'urn': 'urn:li:ugcPost:7041572736007069696',
#    'threadId': 'ugcPost:7041572736007069696',
#    'allowedCommentersScope': 'ALL',
#    'totalSocialActivityCounts': {'socialDetailEntityUrn': 'urn:li:fs_socialDetail:urn:li:ugcPost:7041572736007069696',
#     'urn': 'urn:li:ugcPost:7041572736007069696',
#     'numComments': 3,
#     'dashEntityUrn': 'urn:li:fsd_socialActivityCounts:urn:li:ugcPost:7041572736007069696',
#     'reactionTypeCounts': [{'count': 11, 'reactionType': 'LIKE'},
#      {'count': 4, 'reactionType': 'PRAISE'}],
#     'entityUrn': 'urn:li:fs_socialActivityCounts:urn:li:ugcPost:7041572736007069696',
#     'numShares': 0,
#     'numLikes': 15,
#     'liked': False},
#    'entityUrn': 'urn:li:fs_socialDetail:urn:li:ugcPost:7041572736007069696',
#    'commentingDisabled': False,
#    'likes': {'paging': {'count': 0, 'start': 0, 'total': 15, 'links': []},
#     'elements': []}}},
#  {'actor': {'urn': 'urn:li:member:161574362',
#    'image': {'accessibilityTextAttributes': [],
#     'attributes': [{'sourceType': 'PROFILE_PICTURE',
#       'miniProfile': {'firstName': 'Mireille P.',
#        'lastName': 'Feudjio T. (Ph.D)',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#        'occupation': 'Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life',
#        'objectUrn': 'urn:li:member:161574362',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 756,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1594850407815?e=1745452800&v=beta&t=E54mej56CN7VO4Tf6cqOVfdyk4vWgCeN7R8ymiYhnBU',
#            'expiresAt': 1745452800000,
#            'height': 189},
#           {'width': 756,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1594850407815?e=1745452800&v=beta&t=6f44rst3vHD8lEf5UiXeXJQiTA16XzskxQlJZTsoz9Y',
#            'expiresAt': 1745452800000,
#            'height': 189}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5616AQEwori0Cjg1uw/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'feudjiotmp',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1642571081110?e=1745452800&v=beta&t=Ma00Qth43CNWpaBnrPXxmg03LTbcVxJJloLwURQ7LSQ',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1642571081110?e=1745452800&v=beta&t=kp8k0k29gYnqk1hNDjsRl1qBGgzjZAw-hwSgWgkRbzY',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1642571081110?e=1745452800&v=beta&t=hhSYva3TOt5cLclna7sqUMp6adm0-aR8Fp4f1Fj7R9o',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 612,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1642571081110?e=1745452800&v=beta&t=_OAKfbg3YV_YrlSKLIFOXs_2-QpGVMplnZrkcrnb_MU',
#            'expiresAt': 1745452800000,
#            'height': 612}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5603AQHnaTb2Ddmq0A/profile-displayphoto-shrink_'}},
#        'trackingId': 'KogAEh0bTTSvpf0u3GduRw=='}}]},
#    'supplementaryActorInfo': {'textDirection': 'USER_LOCALE',
#     'accessibilityText': ' • 2nd',
#     'text': ' • 2nd'},
#    'name': {'textDirection': 'FIRST_STRONG',
#     'attributes': [{'start': 0,
#       'length': 29,
#       'miniProfile': {'firstName': 'Mireille P.',
#        'lastName': 'Feudjio T. (Ph.D)',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#        'occupation': 'Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life',
#        'objectUrn': 'urn:li:member:161574362',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 756,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1594850407815?e=1745452800&v=beta&t=E54mej56CN7VO4Tf6cqOVfdyk4vWgCeN7R8ymiYhnBU',
#            'expiresAt': 1745452800000,
#            'height': 189},
#           {'width': 756,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1594850407815?e=1745452800&v=beta&t=6f44rst3vHD8lEf5UiXeXJQiTA16XzskxQlJZTsoz9Y',
#            'expiresAt': 1745452800000,
#            'height': 189}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5616AQEwori0Cjg1uw/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'feudjiotmp',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1642571081110?e=1745452800&v=beta&t=Ma00Qth43CNWpaBnrPXxmg03LTbcVxJJloLwURQ7LSQ',
#            'expiresAt': 1745452800000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1642571081110?e=1745452800&v=beta&t=kp8k0k29gYnqk1hNDjsRl1qBGgzjZAw-hwSgWgkRbzY',
#            'expiresAt': 1745452800000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1642571081110?e=1745452800&v=beta&t=hhSYva3TOt5cLclna7sqUMp6adm0-aR8Fp4f1Fj7R9o',
#            'expiresAt': 1745452800000,
#            'height': 400},
#           {'width': 612,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1642571081110?e=1745452800&v=beta&t=_OAKfbg3YV_YrlSKLIFOXs_2-QpGVMplnZrkcrnb_MU',
#            'expiresAt': 1745452800000,
#            'height': 612}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5603AQHnaTb2Ddmq0A/profile-displayphoto-shrink_'}},
#        'trackingId': 'KogAEh0bTTSvpf0u3GduRw=='},
#       'type': 'PROFILE_FULLNAME'}],
#     'text': 'Mireille P. Feudjio T. (Ph.D)',
#     'accessibilityText': 'Mireille P. Feudjio T. (Ph.D)'},
#    'subDescription': {'textDirection': 'USER_LOCALE',
#     'attributes': [{'start': 6,
#       'length': 1,
#       'artDecoIcon': 'IC_GLOBE_16DP',
#       'type': 'ART_DECO_ICON'}],
#     'text': '2yr •   ',
#     'accessibilityText': '2 years ago'},
#    'navigationContext': {'trackingActionType': 'viewAttributedMember',
#     'accessibilityText': 'View Mireille P. Feudjio T. (Ph.D)’s profile',
#     'actionTarget': 'https://www.linkedin.com/in/feudjiotmp?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo'},
#    'description': {'textDirection': 'USER_LOCALE',
#     'accessibilityText': 'Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life',
#     'text': 'Data Scientist | Machine Learning | Computer Vision | Statistics | Research | Python | R | SQL | GIS | Agriculture | Health | Economy | Sustainability | Better Life'},
#    'followAction': {'followTrackingActionType': 'followMember',
#     'followingInfo': {'followingType': 'DEFAULT',
#      'entityUrn': 'urn:li:fs_followingInfo:urn:li:member:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#      'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_profile:ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#      'following': False,
#      'trackingUrn': 'urn:li:member:161574362'},
#     'unfollowTrackingActionType': 'unfollowMember',
#     'type': 'FOLLOW_TOGGLE',
#     'trackingActionType': 'followMember'}},
#   'dashEntityUrn': 'urn:li:fsd_update:(urn:li:activity:7026268588353159170,MEMBER_SHARES,EMPTY,DEFAULT,false)',
#   'updateMetadata': {'urn': 'urn:li:activity:7026268588353159170',
#    'actionsPosition': 'ACTOR_COMPONENT',
#    'updateActions': {'actions': [{'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_BOOKMARK_OUTLINE_MEDIUM'}]},
#       'actionType': 'SAVE',
#       'saveAction': {'entityUrn': 'urn:li:fs_saveAction:(SAVE,urn:li:activity:7026268588353159170)',
#        'saved': False,
#        'dashEntityUrn': 'urn:li:fsd_saveState:(SAVE,urn:li:activity:7026268588353159170)'},
#       'text': 'Save'},
#      {'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_LINK_MEDIUM'}]},
#       'actionType': 'SHARE_VIA',
#       'text': 'Copy link to post',
#       'url': 'https://www.linkedin.com/posts/feudjiotmp_im-happy-to-share-that-ive-obtained-a-new-activity-7026268588353159170-Q6r3?utm_source=share&utm_medium=member_desktop&rcm=ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk'},
#      {'actionType': 'REPORT',
#       'targetUrn': 'urn:li:ugcPost:7026268587757588480',
#       'contentSource': 'UGC_POST',
#       'authorProfileId': 'ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#       'authorUrn': 'urn:li:member:161574362',
#       'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_REPORT_MEDIUM'}]},
#       'secondaryAction': {'icon': {'accessibilityTextAttributes': [],
#         'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#           'systemImage': 'SYS_ICN_VISIBILITY_OFF_MEDIUM'}]},
#        'actionType': 'HIDE_UPDATE',
#        'targetUrn': 'urn:li:activity:7026268588353159170',
#        'text': 'Hide this post',
#        'confirmationAction': {'title': {'textDirection': 'USER_LOCALE',
#          'text': 'Post removed'},
#         'description': {'textDirection': 'USER_LOCALE',
#          'text': "You'll no longer see this post in your feed."},
#         'undoable': True}},
#       'text': 'Report post',
#       'confirmationAction': {'title': {'textDirection': 'USER_LOCALE',
#         'text': 'Thank you for your report'},
#        'description': {'textDirection': 'USER_LOCALE',
#         'text': 'We appreciate you letting us know'},
#        'undoable': False}}],
#     'entityUrn': 'urn:li:fs_updateV2Actions:(urn:li:activity:7026268588353159170,MEMBER_SHARES,EMPTY,-,-)',
#     'dashEntityUrn': 'urn:li:fsd_updateActions:(urn:li:activity:7026268588353159170,MEMBER_SHARES,EMPTY,urn:li:reason:-,urn:li:adCreative:-)'},
#    'actionTriggerEnabled': False,
#    'detailPageType': 'FEED_DETAIL',
#    'shareAudience': 'PUBLIC',
#    'shareUrn': 'urn:li:ugcPost:7026268587757588480',
#    'excludedFromSeen': False,
#    'rootShare': True,
#    'trackingData': {'requestId': 'f9bba9da-4161-4183-9481-b22fbf1ad556',
#     'trackingId': '6Xg9/Js0dRlH9NEM3ph7fg=='}},
#   'socialContent': {'updateSaveActionToolTipLegoTrackingToken': '...',
#    'shareUrl': 'https://www.linkedin.com/posts/feudjiotmp_im-happy-to-share-that-ive-obtained-a-new-activity-7026268588353159170-Q6r3?utm_source=combined_share_message&utm_medium=member_desktop&rcm=ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk'},
#   'entityUrn': 'urn:li:fs_updateV2:(urn:li:activity:7026268588353159170,MEMBER_SHARES,EMPTY,DEFAULT,false)',
#   'content': {'com.linkedin.voyager.feed.render.CelebrationComponent': {'image': {'accessibilityTextAttributes': [],
#      'attributes': [{'sourceType': 'URL',
#        'imageUrl': 'https://media.licdn.com/media/AAYQAQQSAAgAAQAAAAAAABwEEXEeLoHISM2cU9LdzliLaQ.gif'}]},
#     'headline': {'textDirection': 'USER_LOCALE',
#      'attributes': [],
#      'text': 'Celebrating a New Certification'}}},
#   'commentary': {'numLines': 3,
#    'text': {'textDirection': 'FIRST_STRONG',
#     'attributes': [{'start': 86,
#       'length': 8,
#       'miniCompany': {'objectUrn': 'urn:li:company:3227175',
#        'entityUrn': 'urn:li:fs_miniCompany:3227175',
#        'name': 'DataCamp',
#        'showcase': False,
#        'active': True,
#        'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
# ...
#             'expiresAt': 1747872000000,
#             'height': 100},
#            {'width': 400,
#             'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630518186532/worldagroforestry_logo?e=1747872000&v=beta&t=bQl7HXeD0Li1QdqHayTWoy8e9ZbdlLW_5wFEaSN7-ps',
#             'expiresAt': 1747872000000,
#             'height': 400}],
#           'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQGKQeXWHMg0_w/company-logo_'}},
#         'universalName': 'worldagroforestry',
#         'dashCompanyUrn': 'urn:li:fsd_company:2944074',
#         'trackingId': 'xmBMG3f1SomhH3WcfMgj4A=='},
#        'sourceType': 'COMPANY_LOGO'}]},
#     'name': {'textDirection': 'FIRST_STRONG',
#      'attributes': [{'start': 0,
#        'length': 18,
#        'miniCompany': {'objectUrn': 'urn:li:company:2944074',
#         'entityUrn': 'urn:li:fs_miniCompany:2944074',
#         'name': 'World Agroforestry',
#         'showcase': False,
#         'active': True,
#         'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#             'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630518186532/worldagroforestry_logo?e=1747872000&v=beta&t=DhXir-YeqlF3snO4v6EPs11TzBPzh39xUiS4LGRY6mQ',
#             'expiresAt': 1747872000000,
#             'height': 200},
#            {'width': 100,
#             'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630518186532/worldagroforestry_logo?e=1747872000&v=beta&t=PWXnVjqk-5Iqtx64FZojiTvlAmQpgoooQ_sjyvIHULk',
#             'expiresAt': 1747872000000,
#             'height': 100},
#            {'width': 400,
#             'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630518186532/worldagroforestry_logo?e=1747872000&v=beta&t=bQl7HXeD0Li1QdqHayTWoy8e9ZbdlLW_5wFEaSN7-ps',
#             'expiresAt': 1747872000000,
#             'height': 400}],
#           'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQGKQeXWHMg0_w/company-logo_'}},
#         'universalName': 'worldagroforestry',
#         'dashCompanyUrn': 'urn:li:fsd_company:2944074',
#         'trackingId': 'xmBMG3f1SomhH3WcfMgj4A=='},
#        'type': 'COMPANY_NAME'}],
#      'text': 'World Agroforestry',
#      'accessibilityText': 'World Agroforestry'},
#     'subDescription': {'textDirection': 'USER_LOCALE',
#      'attributes': [{'start': 15,
#        'length': 1,
#        'artDecoIcon': 'IC_GLOBE_16DP',
#        'type': 'ART_DECO_ICON'}],
#      'text': '4yr • Edited •   ',
#      'accessibilityText': '4 years ago'},
#     'navigationContext': {'trackingActionType': 'viewCompany',
#      'accessibilityText': 'View company: World Agroforestry',
#      'actionTarget': 'https://www.linkedin.com/company/worldagroforestry/posts'},
#     'description': {'textDirection': 'USER_LOCALE',
#      'accessibilityText': '98,777 followers',
#      'text': '98,777 followers'},
#     'followAction': {'followTrackingActionType': 'followCompany',
#      'companyFollowingTrackingContext': 'MOBILE_NON_SSU',
#      'followingInfo': {'followingType': 'DEFAULT',
#       'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:2944074',
#       'followerCount': 98777,
#       'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:2944074',
#       'following': False,
#       'trackingUrn': 'urn:li:company:2944074'},
#      'unfollowTrackingActionType': 'unfollowCompany',
#      'type': 'FOLLOW_TOGGLE',
#      'trackingActionType': 'followCompany'}},
#    'dashEntityUrn': 'urn:li:fsd_update:(urn:li:activity:6690927792386797568,MEMBER_SHARES,EMPTY,RESHARED,false)',
#    'updateMetadata': {'urn': 'urn:li:activity:6690927792386797568',
#     'actionsPosition': 'ACTOR_COMPONENT',
#     'updateActions': {'actions': [{'icon': {'accessibilityTextAttributes': [],
#         'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#           'systemImage': 'SYS_ICN_BOOKMARK_OUTLINE_MEDIUM'}]},
#        'actionType': 'SAVE',
#        'saveAction': {'entityUrn': 'urn:li:fs_saveAction:(SAVE,urn:li:activity:6690927792386797568)',
#         'saved': False,
#         'dashEntityUrn': 'urn:li:fsd_saveState:(SAVE,urn:li:activity:6690927792386797568)'},
#        'text': 'Save'},
#       {'icon': {'accessibilityTextAttributes': [],
#         'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#           'systemImage': 'SYS_ICN_LINK_MEDIUM'}]},
#        'actionType': 'SHARE_VIA',
#        'text': 'Copy link to post',
#        'url': 'https://www.linkedin.com/posts/worldagroforestry_expert-assisted-decision-analysis-supports-activity-6690927792386797568-M7W2?utm_source=share&utm_medium=member_desktop&rcm=ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk'},
#       {'actionType': 'REPORT',
#        'targetUrn': 'urn:li:share:6690927791594082305',
#        'contentSource': 'UGC_POST',
#        'authorUrn': 'urn:li:company:2944074',
#        'icon': {'accessibilityTextAttributes': [],
#         'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#           'systemImage': 'SYS_ICN_REPORT_MEDIUM'}]},
#        'text': 'Report post',
#        'confirmationAction': {'title': {'textDirection': 'USER_LOCALE',
#          'text': 'Thank you for your report'},
#         'description': {'textDirection': 'USER_LOCALE',
#          'text': 'We appreciate you letting us know'},
#         'undoable': False}}],
#      'entityUrn': 'urn:li:fs_updateV2Actions:(urn:li:activity:6690927792386797568,MEMBER_SHARES,EMPTY,-,-)',
#      'dashEntityUrn': 'urn:li:fsd_updateActions:(urn:li:activity:6690927792386797568,MEMBER_SHARES,EMPTY,urn:li:reason:-,urn:li:adCreative:-)'},
#     'actionTriggerEnabled': False,
#     'detailPageType': 'FEED_DETAIL',
#     'shouldForceRefetchFromNetwork': True,
#     'shareAudience': 'PUBLIC',
#     'shareUrn': 'urn:li:share:6690927791594082305',
#     'excludedFromSeen': False,
#     'rootShare': True,
#     'trackingData': {'requestId': 'f9bba9da-4161-4183-9481-b22fbf1ad556',
#      'trackingId': 'CXznsGzpfRoMw3GIuLfVzQ=='}},
#    'socialContent': {'updateSaveActionToolTipLegoTrackingToken': '...',
#     'shareUrl': 'https://www.linkedin.com/posts/worldagroforestry_expert-assisted-decision-analysis-supports-activity-6690927792386797568-M7W2?utm_source=combined_share_message&utm_medium=member_desktop&rcm=ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk'},
#    'entityUrn': 'urn:li:fs_updateV2:(urn:li:activity:6690927792386797568,MEMBER_SHARES,EMPTY,RESHARED,false)',
#    'content': {'com.linkedin.voyager.feed.render.ArticleComponent': {'urn': 'urn:li:article:9207337957296511285',
#      'headlineBackgroundColor': 'DEFAULT',
#      'swapTitleAndSubtitle': False,
#      'saveAction': {'entityUrn': 'urn:li:fs_saveAction:(SAVE,urn:li:article:9207337957296511285)',
#       'saved': False,
#       'dashEntityUrn': 'urn:li:fsd_saveState:(SAVE,urn:li:article:9207337957296511285)'},
#      'smallImage': {'accessibilityTextAttributes': [],
#       'attributes': [{'useCropping': True,
#         'sourceType': 'VECTOR',
#         'vectorImage': {'artifacts': [{'width': 800,
#            'fileIdentifyingUrlPathSegment': '800/articleshare-shrink_800/0/1711234129058?e=1740448800&v=beta&t=Fp3Su3vk0s5Ayyt1kWg605aIapTErAVwql52Qqu-upc',
#            'expiresAt': 1740448800000,
#            'height': 418},
#           {'width': 1200,
#            'fileIdentifyingUrlPathSegment': '1280_800/articleshare-shrink_1280_800/0/1711234129058?e=1740448800&v=beta&t=fDDBgfXSWf6JA7zFm_TyA38UF_bkjNqVHlbscrhHoXk',
#            'expiresAt': 1740448800000,
#            'height': 628},
#           {'width': 160,
#            'fileIdentifyingUrlPathSegment': '160/articleshare-shrink_160/0/1711234129058?e=1740448800&v=beta&t=KRG4iKRhoLQg7a2_qbbZ_Y_DihspcBW5F0-aO9dFHsk',
#            'expiresAt': 1740448800000,
#            'height': 83},
#           {'width': 480,
#            'fileIdentifyingUrlPathSegment': '480/articleshare-shrink_480/0/1711234129058?e=1740448800&v=beta&t=cIPE3qLFPEDCmookba_zj8TvVu0nPoVwUu7fHHHL7YI',
#            'expiresAt': 1740448800000,
#            'height': 251}],
#          'rootUrl': 'https://media.licdn.com/dms/image/sync/v2/C4D27AQFf3KARyhV4Dw/articleshare-shrink_'},
#         'displayAspectRatio': 0.5625}]},
#      'subtitle': {'textDirection': 'USER_LOCALE',
#       'text': 'worldagroforestry.org'},
#      'navigationContext': {'trackingActionType': 'viewLink',
#       'accessibilityText': 'Open article: Expert-assisted Decision Analysis supports agroforestry in Viet Nam by worldagroforestry.org',
#       'actionTarget': 'http://www.worldagroforestry.org/blog/2020/07/20/expert-assisted-decision-analysis-supports-agroforestry-viet-nam'},
#      'showSmallTitle': False,
#      'type': 'EXTERNAL_FULL',
#      'title': {'textDirection': 'FIRST_STRONG',
#       'text': 'Expert-assisted Decision Analysis supports agroforestry in Viet Nam'}}},
#    'commentary': {'numLines': 3,
#     'text': {'textDirection': 'FIRST_STRONG',
#      'text': 'Decision-makers on agricultural systems, from farmers to agricultural ministers, should consider ecosystem services, such as water regulation, soil protection, and biodiversity conservation and their trade-offs, but this rarely happens. Selecting appropriate practices for specific locations that are aligned with the needs, values and priorities of farmers is difficult. Researchers are using Decision Analysis to overcome the challenge.\n\nLearn how researchers from World Agroforestry (ICRAF) and  The University of Bonn are using Decision Analysis approaches to support agroforestry in Viet Nam.'}},
#    'socialDetail': {'dashEntityUrn': 'urn:li:fsd_socialDetail:(urn:li:activity:6690927792386797568,urn:li:activity:6690927792386797568,urn:li:highlightedReply:-)',
#     'comments': {'paging': {'start': 0, 'count': 0, 'total': 4, 'links': []},
#      'elements': []},
#     'socialPermissions': {'dashEntityUrn': 'urn:li:fsd_socialPermissions:(urn:li:activity:6690927792386797568,urn:li:fsd_profile:ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk)',
#      'canPostComments': True,
#      'entityUrn': 'urn:li:fs_socialPermissions:(urn:li:activity:6690927792386797568,urn:li:fs_profile:(ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk,en_US))',
#      'messagePermission': 'PUBLIC',
#      'canShare': True,
#      'canReact': True},
#     'showPremiumAnalytics': False,
#     'hideFirstPrompt': True,
#     'liked': False,
#     'showShareButton': True,
#     'totalShares': 32,
#     'urn': 'urn:li:activity:6690927792386797568',
#     'threadId': 'activity:6690927792386797568',
#     'allowedCommentersScope': 'ALL',
#     'totalSocialActivityCounts': {'socialDetailEntityUrn': 'urn:li:fs_socialDetail:urn:li:activity:6690927792386797568',
#      'urn': 'urn:li:activity:6690927792386797568',
#      'numComments': 4,
#      'dashEntityUrn': 'urn:li:fsd_socialActivityCounts:urn:li:activity:6690927792386797568',
#      'reactionTypeCounts': [{'count': 176, 'reactionType': 'LIKE'},
#       {'count': 7, 'reactionType': 'INTEREST'},
#       {'count': 2, 'reactionType': 'EMPATHY'}],
#      'entityUrn': 'urn:li:fs_socialActivityCounts:urn:li:activity:6690927792386797568',
#      'numShares': 32,
#      'numLikes': 185,
#      'liked': False},
#     'entityUrn': 'urn:li:fs_socialDetail:urn:li:activity:6690927792386797568',
#     'commentingDisabled': False,
#     'likes': {'paging': {'start': 0, 'count': 0, 'total': 185, 'links': []},
#      'elements': []}}},
#   'updateMetadata': {'urn': 'urn:li:activity:6693444052949450752',
#    'actionsPosition': 'ACTOR_COMPONENT',
#    'updateActions': {'actions': [{'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_BOOKMARK_OUTLINE_MEDIUM'}]},
#       'actionType': 'SAVE',
#       'saveAction': {'entityUrn': 'urn:li:fs_saveAction:(SAVE,urn:li:activity:6693444052949450752)',
#        'saved': False,
#        'dashEntityUrn': 'urn:li:fsd_saveState:(SAVE,urn:li:activity:6693444052949450752)'},
#       'text': 'Save'},
#      {'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_LINK_MEDIUM'}]},
#       'actionType': 'SHARE_VIA',
#       'text': 'Copy link to post',
#       'url': 'https://www.linkedin.com/posts/feudjiotmp_expert-assisted-decision-analysis-supports-activity-6693444052949450752--ZAI?utm_source=share&utm_medium=member_desktop&rcm=ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk'},
#      {'actionType': 'REPORT',
#       'targetUrn': 'urn:li:share:6693444052412596224',
#       'contentSource': 'UGC_POST',
#       'authorProfileId': 'ACoAAAmhbdoBv1rjZp_ZVkPXvUZLETFSNiCpjeo',
#       'authorUrn': 'urn:li:member:161574362',
#       'icon': {'accessibilityTextAttributes': [],
#        'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#          'systemImage': 'SYS_ICN_REPORT_MEDIUM'}]},
#       'secondaryAction': {'icon': {'accessibilityTextAttributes': [],
#         'attributes': [{'sourceType': 'SYSTEM_IMAGE',
#           'systemImage': 'SYS_ICN_VISIBILITY_OFF_MEDIUM'}]},
#        'actionType': 'HIDE_UPDATE',
#        'targetUrn': 'urn:li:activity:6693444052949450752',
#        'text': 'Hide this post',
#        'confirmationAction': {'title': {'textDirection': 'USER_LOCALE',
#          'text': 'Post removed'},
#         'description': {'textDirection': 'USER_LOCALE',
#          'text': "You'll no longer see this post in your feed."},
#         'undoable': True}},
#       'text': 'Report post',
#       'confirmationAction': {'title': {'textDirection': 'USER_LOCALE',
#         'text': 'Thank you for your report'},
#        'description': {'textDirection': 'USER_LOCALE',
#         'text': 'We appreciate you letting us know'},
#        'undoable': False}}],
#     'entityUrn': 'urn:li:fs_updateV2Actions:(urn:li:activity:6693444052949450752,MEMBER_SHARES,EMPTY,-,-)',
#     'dashEntityUrn': 'urn:li:fsd_updateActions:(urn:li:activity:6693444052949450752,MEMBER_SHARES,EMPTY,urn:li:reason:-,urn:li:adCreative:-)'},
#    'actionTriggerEnabled': False,
#    'shareAudience': 'PUBLIC',
#    'shareUrn': 'urn:li:share:6693444052412596224',
#    'excludedFromSeen': False,
#    'rootShare': False,
#    'trackingData': {'requestId': 'f9bba9da-4161-4183-9481-b22fbf1ad556',
#     'trackingId': 'CXznsGzpfRoMw3GIuLfVzQ=='}},
#   'socialContent': {'updateSaveActionToolTipLegoTrackingToken': '...',
#    'shareUrl': 'https://www.linkedin.com/posts/feudjiotmp_expert-assisted-decision-analysis-supports-activity-6693444052949450752--ZAI?utm_source=combined_share_message&utm_medium=member_desktop&rcm=ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk'},
#   'entityUrn': 'urn:li:fs_updateV2:(urn:li:activity:6693444052949450752,MEMBER_SHARES,EMPTY,DEFAULT,false)',
#   'socialDetail': {'reactionElements': [],
#    'dashEntityUrn': 'urn:li:fsd_socialDetail:(urn:li:activity:6693444052949450752,urn:li:activity:6693444052949450752,urn:li:highlightedReply:-)',
#    'comments': {'paging': {'start': 0, 'count': 0, 'total': 0, 'links': []},
#     'elements': []},
#    'socialPermissions': {'dashEntityUrn': 'urn:li:fsd_socialPermissions:(urn:li:activity:6693444052949450752,urn:li:fsd_profile:ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk)',
#     'canPostComments': True,
#     'entityUrn': 'urn:li:fs_socialPermissions:(urn:li:activity:6693444052949450752,urn:li:fs_profile:(ACoAACFkh60BiGUWCULUkshSJM1dHvbbGs2ebkk,en_US))',
#     'messagePermission': 'PUBLIC',
#     'canShare': True,
#     'canReact': True},
#    'showPremiumAnalytics': False,
#    'hideFirstPrompt': True,
#    'liked': False,
#    'showShareButton': True,
#    'totalShares': 0,
#    'urn': 'urn:li:activity:6693444052949450752',
#    'threadId': 'activity:6693444052949450752',
#    'allowedCommentersScope': 'ALL',
#    'totalSocialActivityCounts': {'socialDetailEntityUrn': 'urn:li:fs_socialDetail:urn:li:activity:6693444052949450752',
#     'urn': 'urn:li:activity:6693444052949450752',
#     'numComments': 0,
#     'dashEntityUrn': 'urn:li:fsd_socialActivityCounts:urn:li:activity:6693444052949450752',
#     'reactionTypeCounts': [{'count': 2, 'reactionType': 'LIKE'}],
#     'entityUrn': 'urn:li:fs_socialActivityCounts:urn:li:activity:6693444052949450752',
#     'numShares': 0,
#     'numLikes': 2,
#     'liked': False},
#    'entityUrn': 'urn:li:fs_socialDetail:urn:li:activity:6693444052949450752',
#    'commentingDisabled': False,
#    'likes': {'paging': {'count': 0, 'start': 0, 'total': 2, 'links': []},
#     'elements': []}}}]

# %%
api1 = Linkedin('3chamois-bifocal@icloud.com', 'cinnyn-surfix-8Cejji')

# %%
people1 =  api.search_people(
    keywords="nlp computer vision",
    regions = ['103644278',],
    limit=100
)

# %%
pd.DataFrame(people1)
# Out:
#                                      urn_id    distance  \
# 0   ACoAAClJ0KIByWONXQxwFvByOLkE3MeNrVxNHI4  DISTANCE_3
# 1   ACoAAAOLxVsBnDFVVv4ncvq8-ZdAAp6_xwOEvWo  DISTANCE_2
# 2   ACoAAAkAqbMBPyR6myDSmEyLNtbHWGXkrhDo3tA  DISTANCE_3
# 3   ACoAABC84HMBENy4mjh9YqZ0bIewbNnstGeaEJA  DISTANCE_2
# 4   ACoAAAWTT-MB23AeG-R2yjf_ufXqnQMikPh0xq4  DISTANCE_3
# ..                                      ...         ...
# 95  ACoAACfCzjYBriouLBmed2McO0lxqHtdx5J-rQ8  DISTANCE_2
# 96  ACoAAAm4ZoMBYsCuF2aCp9TSQJa6uFAmZbQ67IQ  DISTANCE_3
# 97  ACoAABlKsiIBTJLE-Cc6Qax7L9d9cwLe6lfkjLI  DISTANCE_3
# 98  ACoAADitpOsBmzC97lGFN05jsPTN-J8-hIFYRA4  DISTANCE_3
# 99  ACoAADUdSqkByHpuqdA7CVtLFYAIScSQxsuBSoI  DISTANCE_3
#
#                                              jobtitle  \
# 0   NLP | Computer Vision | Deep Learning | Data S...
# 1    Data Scientist | AI | ML | Computer Vision | NLP
# 2   Senior Machine Learning Engineer | Deep Learni...
# 3   ML SWE @ Meta | Deep Learning | NLP | Computer...
# 4   Applied Scientist at Adobe | Researcher - Gene...
# ..                                                ...
# 95  Machine Learning Engineer | Applied Scientist ...
# 96              LLMs | Gen AI | NLP | Computer Vision
# 97  Gen AI Engineer | Machine Learning| Data Scien...
# 98  Seeking Full-time Opportunities | Intern at ap...
# 99  AI Enthusiast | Computer Vision | NLP | ML | A...
#
#                      location                             name
# 0                  Austin, TX                    Rakesh Ramesh
# 1   Atlanta Metropolitan Area                      Suresh Mani
# 2               United States        Zahra Anvari, (PhD in AI)
# 3              Menlo Park, CA             Aishwarya Paraspatki
# 4                San Jose, CA         Shabhareesh Komirishetty
# ..                        ...                              ...
# 95               San Jose, CA                  Parth Shettiwar
# 96     San Francisco Bay Area          Negar M. Shakiba, Ph.D.
# 97                Chicago, IL                   Nihar Muniraju
# 98                Buffalo, NY  Venkata Ramana Reddy Duggempudi
# 99              United States                    Javaria Latif
#
# [100 rows x 5 columns]
